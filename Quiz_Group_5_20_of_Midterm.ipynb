# %% [markdown]
# <a href="https://colab.research.google.com/github/SasiwimonV/bsc_dpdm22/blob/main/Quiz_Group_5_20_of_Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #ความกดอากาศ K

# %%
#นำข้อมูลเข้า เปลียนชื่อคอลัมบ์
KKH1 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความกด(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34':'ความกด'})
KNA1 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความกด(เปอร์เซ็นต์)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความกด'})
KSA1 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความกด(เปอร์เซ็นต์)/จ.สกลนคร.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความกด'})
KNO1 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความกด(เปอร์เซ็นต์)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความกด'})
KLO1 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความกด(เปอร์เซ็นต์)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความกด'})

KKH1['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
KNA1['จังหวัด'] = 'นครพนม'
KSA1['จังหวัด'] = 'สกลนคร'
KNO1['จังหวัด'] = 'หนองคาย'
KLO1['จังหวัด'] = 'เลย'
KKH1.head()
# Out:
#    ที่                     สถานี   เดือน/ปี        1        2        3  \
# 0  1    352201-หนองคาย จ.หนองคาย 2011-10-01  1005.47  1006.65  1007.49
# 1  2    352201-หนองคาย จ.หนองคาย 2011-11-01  1011.79  1010.83  1010.74
# 2  3    352201-หนองคาย จ.หนองคาย 2011-12-01  1011.43  1012.57  1012.28
# 3  1    352201-หนองคาย จ.หนองคาย 2012-01-01  1015.67  1014.11  1012.91
# 4  2    352201-หนองคาย จ.หนองคาย 2012-02-01  1013.26  1012.92  1013.61
#
#          4        5        6        7  ...       24       25       26  \
# 0  1008.28  1009.88  1011.36  1011.17  ...  1010.23  1011.34  1011.84
# 1  1010.71  1010.09  1009.24  1008.03  ...  1015.40  1013.95  1012.35
# 2  1012.97  1013.09  1012.03  1012.05  ...  1015.78  1018.56  1018.65
# 3  1014.06  1015.51  1015.88  1017.72  ...  1011.27  1011.65  1012.56
# 4  1013.18  1011.26  1008.80  1008.16  ...  1005.46  1004.80  1005.08
#
#         27       28       29       30       31       ความกด  จังหวัด
# ...

# %%
KKH1.shape
# Out:
# (55, 36)

# %%
#เลือกดูเฉพาะขอนแก่นว่าข้อมูลมีทั้งหมดกี่เดือน กี่วัน
list_1=list()
for i in range(31):
  i+=1
  list_1.append(i)
KKH_1=KKH1[list_1].T
KKH_1
# Out:
#          0        1        2        3        4        5        6        7   \
# 1   1005.47  1011.79  1011.43  1015.67  1013.26   1011.5  1012.67   1009.8
# 2   1006.65  1010.83  1012.57  1014.11  1012.92  1011.11  1011.17  1010.17
# 3   1007.49  1010.74  1012.28  1012.91  1013.61   1008.6  1010.47  1010.74
# 4   1008.28  1010.71  1012.97  1014.06  1013.18  1007.07  1010.24  1010.72
# 5   1009.88  1010.09  1013.09  1015.51  1011.26  1008.17  1010.43  1010.61
# 6   1011.36  1009.24  1012.03  1015.88   1008.8  1010.06   1010.9  1012.15
# 7   1011.17  1008.03  1012.05  1017.72  1008.16  1010.11  1009.76  1011.02
# 8    1010.2   1007.2  1011.94  1018.06  1009.66  1010.07  1008.36  1011.34
# 9   1010.14  1009.68  1014.29  1016.98  1011.25  1010.56  1008.55  1010.76
# 10   1010.6  1011.96   1016.1  1016.18  1011.42  1011.39  1009.21  1010.29
# 11  1010.04  1012.75  1017.69  1016.16  1012.09  1011.03  1009.95  1010.88
# ...

# %%
# #เลือกดูเฉพาะความกดว่าข้อมูลมีทั้งหมดกี่เดือน
# list_1=list()
# for i in range(31):
#   i+=1
#   list_1.append(i)
# p=allpres[list_1].T
# p

# %% [markdown]
# ##รวมตารางความกดอากาศ

# %%
pressure = [KKH1, KNA1, KSA1, KNO1, KLO1] #ความกดอากาศ
allpres = pd.concat(pressure)
allpres.head()
# Out:
#    ที่                     สถานี   เดือน/ปี        1        2        3  \
# 0  1    352201-หนองคาย จ.หนองคาย 2011-10-01  1005.47  1006.65  1007.49
# 1  2    352201-หนองคาย จ.หนองคาย 2011-11-01  1011.79  1010.83  1010.74
# 2  3    352201-หนองคาย จ.หนองคาย 2011-12-01  1011.43  1012.57  1012.28
# 3  1    352201-หนองคาย จ.หนองคาย 2012-01-01  1015.67  1014.11  1012.91
# 4  2    352201-หนองคาย จ.หนองคาย 2012-02-01  1013.26  1012.92  1013.61
#
#          4        5        6        7  ...       24       25       26  \
# 0  1008.28  1009.88  1011.36  1011.17  ...  1010.23  1011.34  1011.84
# 1  1010.71  1010.09  1009.24  1008.03  ...  1015.40  1013.95  1012.35
# 2  1012.97  1013.09  1012.03  1012.05  ...  1015.78  1018.56  1018.65
# 3  1014.06  1015.51  1015.88  1017.72  ...  1011.27  1011.65  1012.56
# 4  1013.18  1011.26  1008.80  1008.16  ...  1005.46  1004.80  1005.08
#
#         27       28       29       30       31       ความกด  จังหวัด
# ...

# %%
allpres.shape
# Out:
# (275, 36)

# %%
allpres['เดือน'] = allpres['เดือน/ปี'].dt.month #การแยกเดือนปี
allpres['ปี'] = allpres['เดือน/ปี'].dt.year
del allpres['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
allpres.head()
# Out:
#    ที่                     สถานี        1        2        3        4        5  \
# 0  1    352201-หนองคาย จ.หนองคาย  1005.47  1006.65  1007.49  1008.28  1009.88
# 1  2    352201-หนองคาย จ.หนองคาย  1011.79  1010.83  1010.74  1010.71  1010.09
# 2  3    352201-หนองคาย จ.หนองคาย  1011.43  1012.57  1012.28  1012.97  1013.09
# 3  1    352201-หนองคาย จ.หนองคาย  1015.67  1014.11  1012.91  1014.06  1015.51
# 4  2    352201-หนองคาย จ.หนองคาย  1013.26  1012.92  1013.61  1013.18  1011.26
#
#          6        7        8  ...       26       27       28       29  \
# 0  1011.36  1011.17  1010.20  ...  1011.84  1011.89  1012.29  1011.67
# 1  1009.24  1008.03  1007.20  ...  1012.35  1011.31  1009.59  1010.13
# 2  1012.03  1012.05  1011.94  ...  1018.65  1016.88  1016.05  1014.98
# 3  1015.88  1017.72  1018.06  ...  1012.56  1010.76  1010.26  1010.69
# 4  1008.80  1008.16  1009.66  ...  1005.08  1006.57  1005.96  1006.53
#
#         30       31       ความกด  จังหวัด  เดือน    ปี
# ...

# %%
allpres.shape
# Out:
# (275, 37)

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
p = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in allpres.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
         print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ความกด -> ',row[i],row['จังหวัด'])
         p.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ความกด',row[i]])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# วันที่  23 เดือนที่  1  ปีที่  2012 ความกด ->  1012.8 สกลนคร
# วันที่  24 เดือนที่  1  ปีที่  2012 ความกด ->  1012.37 สกลนคร
# วันที่  25 เดือนที่  1  ปีที่  2012 ความกด ->  1013.47 สกลนคร
# วันที่  26 เดือนที่  1  ปีที่  2012 ความกด ->  1013.39 สกลนคร
# วันที่  27 เดือนที่  1  ปีที่  2012 ความกด ->  1011.36 สกลนคร
# วันที่  28 เดือนที่  1  ปีที่  2012 ความกด ->  1010.64 สกลนคร
# วันที่  29 เดือนที่  1  ปีที่  2012 ความกด ->  1011.95 สกลนคร
# วันที่  30 เดือนที่  1  ปีที่  2012 ความกด ->  1013.86 สกลนคร
# วันที่  31 เดือนที่  1  ปีที่  2012 ความกด ->  1015.52 สกลนคร
# วันที่  1 เดือนที่  2  ปีที่  2012 ความกด ->  1014.05 สกลนคร
# วันที่  2 เดือนที่  2  ปีที่  2012 ความกด ->  1013.71 สกลนคร
# วันที่  3 เดือนที่  2  ปีที่  2012 ความกด ->  1014.95 สกลนคร
# วันที่  4 เดือนที่  2  ปีที่  2012 ความกด ->  1013.68 สกลนคร
# วันที่  5 เดือนที่  2  ปีที่  2012 ความกด ->  1011.72 สกลนคร
# ...

# %%
pk = pd.DataFrame(p)
pk
# Out:
#             0        1   2          3   4        5     6       7        8
# 0     ขอนแก่น  วันที่    1  เดือนที่   10   ปีที่   2011  ความกด  1005.47
# 1     ขอนแก่น  วันที่    2  เดือนที่   10   ปีที่   2011  ความกด  1006.65
# 2     ขอนแก่น  วันที่    3  เดือนที่   10   ปีที่   2011  ความกด  1007.49
# 3     ขอนแก่น  วันที่    4  เดือนที่   10   ปีที่   2011  ความกด  1008.28
# 4     ขอนแก่น  วันที่    5  เดือนที่   10   ปีที่   2011  ความกด  1009.88
# ...       ...      ...  ..        ...  ..      ...   ...     ...      ...
# 8520      เลย  วันที่   27  เดือนที่    2   ปีที่   2022  ความกด  1014.97
# 8521      เลย  วันที่   28  เดือนที่    2   ปีที่   2022  ความกด  1012.88
# 8522      เลย  วันที่   29  เดือนที่    2   ปีที่   2022  ความกด        -
# 8523      เลย  วันที่   30  เดือนที่    2   ปีที่   2022  ความกด        -
# 8524      เลย  วันที่   31  เดือนที่    2   ปีที่   2022  ความกด        -
#
# [8525 rows x 9 columns]

# %%
pk = pd.DataFrame(p, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','ความกด'])
pk
# Out:
#       จังหวัด        0  วันที่          1  เดือนที่        2  ปีที่       3  \
# 0     ขอนแก่น  วันที่        1  เดือนที่         10   ปีที่    2011  ความกด
# 1     ขอนแก่น  วันที่        2  เดือนที่         10   ปีที่    2011  ความกด
# 2     ขอนแก่น  วันที่        3  เดือนที่         10   ปีที่    2011  ความกด
# 3     ขอนแก่น  วันที่        4  เดือนที่         10   ปีที่    2011  ความกด
# 4     ขอนแก่น  วันที่        5  เดือนที่         10   ปีที่    2011  ความกด
# ...       ...      ...     ...        ...       ...      ...    ...     ...
# 8520      เลย  วันที่       27  เดือนที่          2   ปีที่    2022  ความกด
# 8521      เลย  วันที่       28  เดือนที่          2   ปีที่    2022  ความกด
# 8522      เลย  วันที่       29  เดือนที่          2   ปีที่    2022  ความกด
# 8523      เลย  วันที่       30  เดือนที่          2   ปีที่    2022  ความกด
# 8524      เลย  วันที่       31  เดือนที่          2   ปีที่    2022  ความกด
#
#        ความกด
# 0     1005.47
# 1     1006.65
# ...

# %%
pk.drop(['0', '1', '2','3'], 1, inplace=True)
# Out:
# <ipython-input-14-12aae03e1e85>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   pk.drop(['0', '1', '2','3'], 1, inplace=True)

# %%
pk
# Out:
#       จังหวัด  วันที่  เดือนที่  ปีที่   ความกด
# 0     ขอนแก่น       1        10   2011  1005.47
# 1     ขอนแก่น       2        10   2011  1006.65
# 2     ขอนแก่น       3        10   2011  1007.49
# 3     ขอนแก่น       4        10   2011  1008.28
# 4     ขอนแก่น       5        10   2011  1009.88
# ...       ...     ...       ...    ...      ...
# 8520      เลย      27         2   2022  1014.97
# 8521      เลย      28         2   2022  1012.88
# 8522      เลย      29         2   2022        -
# 8523      เลย      30         2   2022        -
# 8524      เลย      31         2   2022        -
#
# [8525 rows x 5 columns]

# %% [markdown]
# #ความชื้นสัมพัทธ์ C

# %%
CKH2 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความชื้นสัมพัทธ์(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความชื้น'})
CNA2 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความชื้นสัมพัทธ์(เปอร์เซ็นต์)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความชื้น'})
CSA2 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความชื้นสัมพัทธ์(เปอร์เซ็นต์)/จ.สกลนคร.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความชื้น'})
CNO2 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความชื้นสัมพัทธ์(เปอร์เซ็นต์)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความชื้น'})
CLO2 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความชื้นสัมพัทธ์(เปอร์เซ็นต์)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความชื้น'})

CKH2['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
CNA2['จังหวัด'] = 'นครพนม'
CSA2['จังหวัด'] = 'สกลนคร'
CNO2['จังหวัด'] = 'หนองคาย'
CLO2['จังหวัด'] = 'เลย'
CLO2.head()
# Out:
#    ที่                  สถานี   เดือน/ปี   1   2   3   4   5   6   7  ...  24  \
# 0  1    353301-เลย สกษ. จ.เลย 2011-10-01  90  95  92  89  86  94  90  ...  86
# 1  2    353301-เลย สกษ. จ.เลย 2011-11-01  85  83  84  83  83  85  83  ...  77
# 2  3    353301-เลย สกษ. จ.เลย 2011-12-01  80  77  77  76  78  83  82  ...  74
# 3  1    353301-เลย สกษ. จ.เลย 2012-01-01  75  78  81  79  73  77  82  ...  80
# 4  2    353301-เลย สกษ. จ.เลย 2012-02-01  79  81  91  84  78  73  69  ...  68
#
#    25  26  27  28  29  30  31  ความชื้น  จังหวัด
# 0  83  84  85  85  82  83  85        87      เลย
# 1  80  81  80  84  82  79   -        82      เลย
# 2  75  74  80  80  78  81  78        77      เลย
# 3  83  79  80  78  77  82  79        78      เลย
# 4  68  67  76  73  70   -   -        73      เลย
#
# [5 rows x 36 columns]

# %% [markdown]
# ##รวมตารางความชื้นสัมพัทธ์

# %%
RH = [CKH2, CNA2, CSA2, CNO2, CLO2] #ความชื้นสัมพัทธ์
allrh = pd.concat(RH)
allrh.head()
# Out:
#    ที่                     สถานี   เดือน/ปี   1   2   3   4   5   6   7  ...  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น 2011-10-01  83  92  86  80  86  86  83  ...
# 1  2    381201-ขอนแก่น จ.ขอนแก่น 2011-11-01  71  65  68  65  65  68  69  ...
# 2  3    381201-ขอนแก่น จ.ขอนแก่น 2011-12-01  66  61  61  62  61  60  69  ...
# 3  1    381201-ขอนแก่น จ.ขอนแก่น 2012-01-01  65  66  69  63  64  68  65  ...
# 4  2    381201-ขอนแก่น จ.ขอนแก่น 2012-02-01  71  72  71  72  70  68  61  ...
#
#    24  25  26  27  28  29  30  31  ความชื้น  จังหวัด
# 0  72  73  69  69  75  71  71  68        79  ขอนแก่น
# 1  66  65  67  68  67  67  65   -        68  ขอนแก่น
# 2  62  60  60  62  65  66  63  64        63  ขอนแก่น
# 3  74  75  71  75  69  70  67  68        69  ขอนแก่น
# 4  53  48  57  71  73  68   -   -        65  ขอนแก่น
#
# [5 rows x 36 columns]

# %%
allrh['เดือน'] = allrh['เดือน/ปี'].dt.month #การแยกเดือนปี
allrh['ปี'] = allrh['เดือน/ปี'].dt.year
del allrh['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
allrh.head()
# Out:
#    ที่                     สถานี   1   2   3   4   5   6   7   8  ...  26  27  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น  83  92  86  80  86  86  83  82  ...  69  69
# 1  2    381201-ขอนแก่น จ.ขอนแก่น  71  65  68  65  65  68  69  69  ...  67  68
# 2  3    381201-ขอนแก่น จ.ขอนแก่น  66  61  61  62  61  60  69  68  ...  60  62
# 3  1    381201-ขอนแก่น จ.ขอนแก่น  65  66  69  63  64  68  65  62  ...  71  75
# 4  2    381201-ขอนแก่น จ.ขอนแก่น  71  72  71  72  70  68  61  69  ...  57  71
#
#    28  29  30  31  ความชื้น  จังหวัด  เดือน    ปี
# 0  75  71  71  68        79  ขอนแก่น     10  2011
# 1  67  67  65   -        68  ขอนแก่น     11  2011
# 2  65  66  63  64        63  ขอนแก่น     12  2011
# 3  69  70  67  68        69  ขอนแก่น      1  2012
# 4  73  68   -   -        65  ขอนแก่น      2  2012
#
# [5 rows x 37 columns]

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
h = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in allrh.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
        #  print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ความชื้นสัมพัทธ์ -> ',row[i],row['จังหวัด'])
         h.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ความชื้นสัมพัทธ์',row[i]])

# %%
hk = pd.DataFrame(h)
hk = pd.DataFrame(h, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','ความชื้นสัมพัทธ์'])
hk.drop(['0', '1', '2','3'], 1, inplace=True)
hk
# Out:
# <ipython-input-20-69791f7535ae>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   hk.drop(['0', '1', '2','3'], 1, inplace=True)
#       จังหวัด  วันที่  เดือนที่  ปีที่ ความชื้นสัมพัทธ์
# 0     ขอนแก่น       1        10   2011               83
# 1     ขอนแก่น       2        10   2011               92
# 2     ขอนแก่น       3        10   2011               86
# 3     ขอนแก่น       4        10   2011               80
# 4     ขอนแก่น       5        10   2011               86
# ...       ...     ...       ...    ...              ...
# 8520      เลย      27         2   2022               74
# 8521      เลย      28         2   2022               72
# 8522      เลย      29         2   2022                -
# 8523      เลย      30         2   2022                -
# 8524      เลย      31         2   2022                -
#
# [8525 rows x 5 columns]

# %% [markdown]
# #ความเร็วลม S

# %%
SKH3 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความเร็วลม(นอต)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความเร็วลม'})
SNA3 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความเร็วลม(นอต)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความเร็วลม'})
SSA3 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความเร็วลม(นอต)/จ.สกลนคร.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความเร็วลม'})
SNO3 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความเร็วลม(นอต)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความเร็วลม'})
SLO3 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ความเร็วลม(นอต)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ความเร็วลม'})

SKH3['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
SNA3['จังหวัด'] = 'นครพนม'
SSA3['จังหวัด'] = 'สกลนคร'
SNO3['จังหวัด'] = 'หนองคาย'
SLO3['จังหวัด'] = 'เลย'
SLO3.head()
# Out:
#    ที่                  สถานี   เดือน/ปี  1  2  3  4  5  6  7  ...  24  25  \
# 0  1    353301-เลย สกษ. จ.เลย 2011-10-01  2  2  3  2  3  2  1  ...   1   2
# 1  2    353301-เลย สกษ. จ.เลย 2011-11-01  1  2  1  1  2  2  2  ...   2   1
# 2  3    353301-เลย สกษ. จ.เลย 2011-12-01  2  2  3  2  1  2  1  ...   2   3
# 3  1    353301-เลย สกษ. จ.เลย 2012-01-01  2  2  1  2  2  2  2  ...   1   3
# 4  2    353301-เลย สกษ. จ.เลย 2012-02-01  1  2  2  1  1  2  1  ...   1   1
#
#    26  27  28  29  30  31 ความเร็วลม  จังหวัด
# 0   2   1   2   2   2   1   1.612903      เลย
# 1   1   2   1   2   1   -   1.700000      เลย
# 2   2   1   2   1   2   2   1.870968      เลย
# 3   2   2   2   2   1   1   1.838710      เลย
# 4   1   3   4   2   1   -   1.700000      เลย
#
# [5 rows x 36 columns]

# %% [markdown]
# ##รวมตารางความเร็วลม

# %%
wind = [SKH3, SNA3, SSA3, SNO3, SLO3] #ความเร็วลม
allwind = pd.concat(wind)
allwind.head()
# Out:
#    ที่                  สถานี   เดือน/ปี  1  2  3  4  5  6  7  ... 24  25 26  \
# 0  1    353301-เลย สกษ. จ.เลย 2011-10-01  3  2  3  2  2  3  4  ...  3   5  5
# 1  2    353301-เลย สกษ. จ.เลย 2011-11-01  4  5  3  3  5  2  3  ...  6   5  5
# 2  3    353301-เลย สกษ. จ.เลย 2011-12-01  3  4  4  4  4  4  4  ...  6   7  6
# 3  1    353301-เลย สกษ. จ.เลย 2012-01-01  4  2  1  4  4  2  4  ...  3   4  2
# 4  2    353301-เลย สกษ. จ.เลย 2012-02-01  2  2  3  2  3  1  2  ...  2   3  2
#
#   27 28  29  30 31 ความเร็วลม  จังหวัด
# 0  5  4   6   4  5   3.354839  ขอนแก่น
# 1  3  1   3   3  -   3.466667  ขอนแก่น
# 2  5  4   4   6  5   4.806452  ขอนแก่น
# 3  2  1   3   4  4   3.129032  ขอนแก่น
# 4  4  3   3   3  -   2.566667  ขอนแก่น
#
# [5 rows x 36 columns]

# %%
allwind['เดือน'] = allwind['เดือน/ปี'].dt.month #การแยกเดือนปี
allwind['ปี'] = allwind['เดือน/ปี'].dt.year
del allwind['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
allwind.head()
# Out:
#    ที่                  สถานี  1  2  3  4  5  6  7  8  ...  26 27 28 29  30  \
# 0  1    353301-เลย สกษ. จ.เลย  3  2  3  2  2  3  4  3  ...   5  5  4  6   4
# 1  2    353301-เลย สกษ. จ.เลย  4  5  3  3  5  2  3  3  ...   5  3  1  3   3
# 2  3    353301-เลย สกษ. จ.เลย  3  4  4  4  4  4  4  4  ...   6  5  4  4   6
# 3  1    353301-เลย สกษ. จ.เลย  4  2  1  4  4  2  4  6  ...   2  2  1  3   4
# 4  2    353301-เลย สกษ. จ.เลย  2  2  3  2  3  1  2  3  ...   2  4  3  3   3
#
#    31 ความเร็วลม  จังหวัด  เดือน    ปี
# 0   5   3.354839  ขอนแก่น     10  2011
# 1   -   3.466667  ขอนแก่น     11  2011
# 2   5   4.806452  ขอนแก่น     12  2011
# 3   4   3.129032  ขอนแก่น      1  2012
# 4   -   2.566667  ขอนแก่น      2  2012
#
# [5 rows x 37 columns]

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
w = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in allwind.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
        #  print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ความเร็วลม -> ',row[i],row['จังหวัด'])
         w.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ความเร็วลม',row[i]])

# %%
wk = pd.DataFrame(w)
wk = pd.DataFrame(w, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','ความเร็วลม'])
wk.drop(['0', '1', '2','3'], 1, inplace=True)
wk
# Out:
# <ipython-input-25-c9b737a82d53>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   wk.drop(['0', '1', '2','3'], 1, inplace=True)
#       จังหวัด  วันที่  เดือนที่  ปีที่ ความเร็วลม
# 0     ขอนแก่น       1        10   2011          3
# 1     ขอนแก่น       2        10   2011          2
# 2     ขอนแก่น       3        10   2011          3
# 3     ขอนแก่น       4        10   2011          2
# 4     ขอนแก่น       5        10   2011          2
# ...       ...     ...       ...    ...        ...
# 8520      เลย      27         2   2022          1
# 8521      เลย      28         2   2022          1
# 8522      เลย      29         2   2022          -
# 8523      เลย      30         2   2022          -
# 8524      เลย      31         2   2022          -
#
# [8525 rows x 5 columns]

# %% [markdown]
# #จำนวนเมฆ CL

# %%
CLKH4 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/จำนวนเมฆ(10ส่วน)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'จำนวนเมฆ'})
CLNA4 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/จำนวนเมฆ(10ส่วน)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'จำนวนเมฆ'})
CLSA4 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/จำนวนเมฆ(10ส่วน)/จ.สกลนคร.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'จำนวนเมฆ'})
CLNO4 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/จำนวนเมฆ(10ส่วน)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'จำนวนเมฆ'})
CLLO4 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/จำนวนเมฆ(10ส่วน)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).iloc[:,:35].rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'จำนวนเมฆ'})

CLKH4['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
CLNA4['จังหวัด'] = 'นครพนม'
CLSA4['จังหวัด'] = 'สกลนคร'
CLNO4['จังหวัด'] = 'หนองคาย'
CLLO4['จังหวัด'] = 'เลย'
CLLO4.head()
# Out:
#    ที่                  สถานี   เดือน/ปี  1   2   3  4  5   6   7  ... 24 25  \
# 0  1    353301-เลย สกษ. จ.เลย 2011-10-01  8  10  10  9  8  10  10  ...  1  2
# 1  2    353301-เลย สกษ. จ.เลย 2011-11-01  2   1   2  1  1   1   2  ...  4  0
# 2  3    353301-เลย สกษ. จ.เลย 2011-12-01  1   3   1  3  3   2   3  ...  1  1
# 3  1    353301-เลย สกษ. จ.เลย 2012-01-01  1   1   3  6  6   2   1  ...  4  6
# 4  2    353301-เลย สกษ. จ.เลย 2012-02-01  8   5  10  7  1   0   -  ...  -  -
#
#   26 27 28 29 30 31  จำนวนเมฆ จังหวัด
# 0  4  2  3  3  1  2  5.387097     เลย
# 1  1  2  2  5  3  -  2.333333     เลย
# 2  0  0  1  1  4  1  2.354839     เลย
# 3  5  1  2  4  9  8  3.870968     เลย
# 4  0  1  3  -  3  -  2.809524     เลย
#
# [5 rows x 36 columns]

# %% [markdown]
# ##รวมตารางจำนวนเมฆ

# %%
cloud = [CLKH4, CLNA4, CLSA4, CLNO4, CLLO4] #ปริมาณเมฆ
allcloud = pd.concat(cloud)
allcloud.head()
# Out:
#    ที่                  สถานี   เดือน/ปี  1   2   3  4   5   6   7  ... 24 25  \
# 0  1    353301-เลย สกษ. จ.เลย 2011-10-01  9  10  10  8  10  10  10  ...  3  5
# 1  2    353301-เลย สกษ. จ.เลย 2011-11-01  2   2   2  2   3   6   9  ...  6  3
# 2  3    353301-เลย สกษ. จ.เลย 2011-12-01  2   3   4  4   5   8   7  ...  5  3
# 3  1    353301-เลย สกษ. จ.เลย 2012-01-01  1   4   7  6   3   1   3  ...  4  4
# 4  2    353301-เลย สกษ. จ.เลย 2012-02-01  6   6   8  8   3   3   1  ...  2  0
#
#   26 27 28 29  30  31  จำนวนเมฆ  จังหวัด
# 0  3  3  5  4   2   2  6.322581  ขอนแก่น
# 1  2  2  1  3   2   -  3.533333  ขอนแก่น
# 2  3  1  2  1   1   1  3.516129  ขอนแก่น
# 3  3  2  5  6  10  10  5.354839  ขอนแก่น
# 4  1  4  5  1   2   -  2.533333  ขอนแก่น
#
# [5 rows x 36 columns]

# %%
allcloud['เดือน'] = allcloud['เดือน/ปี'].dt.month #การแยกเดือนปี
allcloud['ปี'] = allcloud['เดือน/ปี'].dt.year
del allcloud['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
allcloud.head()
# Out:
#    ที่                  สถานี  1   2   3  4   5   6   7  8  ... 26 27 28 29  \
# 0  1    353301-เลย สกษ. จ.เลย  9  10  10  8  10  10  10  7  ...  3  3  5  4
# 1  2    353301-เลย สกษ. จ.เลย  2   2   2  2   3   6   9  6  ...  2  2  1  3
# 2  3    353301-เลย สกษ. จ.เลย  2   3   4  4   5   8   7  6  ...  3  1  2  1
# 3  1    353301-เลย สกษ. จ.เลย  1   4   7  6   3   1   3  3  ...  3  2  5  6
# 4  2    353301-เลย สกษ. จ.เลย  6   6   8  8   3   3   1  2  ...  1  4  5  1
#
#    30  31  จำนวนเมฆ  จังหวัด เดือน    ปี
# 0   2   2  6.322581  ขอนแก่น    10  2011
# 1   2   -  3.533333  ขอนแก่น    11  2011
# 2   1   1  3.516129  ขอนแก่น    12  2011
# 3  10  10  5.354839  ขอนแก่น     1  2012
# 4   2   -  2.533333  ขอนแก่น     2  2012
#
# [5 rows x 37 columns]

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
c = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in allcloud.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
        #  print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'จำนวนเมฆ -> ',row[i],row['จังหวัด'])
         c.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'จำนวนเมฆ',row[i]])

ck = pd.DataFrame(c)
ck = pd.DataFrame(c, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','จำนวนเมฆ'])
ck.drop(['0', '1', '2','3'], 1, inplace=True)
ck
# Out:
# <ipython-input-29-386856963272>:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   ck.drop(['0', '1', '2','3'], 1, inplace=True)
#       จังหวัด  วันที่  เดือนที่  ปีที่ จำนวนเมฆ
# 0     ขอนแก่น       1        10   2011        9
# 1     ขอนแก่น       2        10   2011       10
# 2     ขอนแก่น       3        10   2011       10
# 3     ขอนแก่น       4        10   2011        8
# 4     ขอนแก่น       5        10   2011       10
# ...       ...     ...       ...    ...      ...
# 8520      เลย      27         2   2022        3
# 8521      เลย      28         2   2022        2
# 8522      เลย      29         2   2022        -
# 8523      เลย      30         2   2022        -
# 8524      เลย      31         2   2022        -
#
# [8525 rows x 5 columns]

# %% [markdown]
# #ปริมาณฝน R

# %%
RKH5 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ปริมาณฝน(มิลลิเมตร)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ปริมาณฝน'})
RNA5 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ปริมาณฝน(มิลลิเมตร)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ปริมาณฝน'})
RSA5 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ปริมาณฝน(มิลลิเมตร)/จ.สกล.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ปริมาณฝน'})
RNO5 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ปริมาณฝน(มิลลิเมตร)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ปริมาณฝน'})
RLO5 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/ปริมาณฝน(มิลลิเมตร)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'ปริมาณฝน'})

RKH5['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
RNA5['จังหวัด'] = 'นครพนม'
RSA5['จังหวัด'] = 'สกลนคร'
RNO5['จังหวัด'] = 'หนองคาย'
RLO5['จังหวัด'] = 'เลย'
RLO5.head()
# Out:
#    ที่             สถานี   เดือน/ปี     1      2    3  4  5    6    7  ... 24  \
# 0  1    353201-เลย จ.เลย 2011-10-01  21.6  111.4  0.4  0  0  3.4  1.8  ...  0
# 1  2    353201-เลย จ.เลย 2011-11-01     0      0    0  0  0    0    0  ...  0
# 2  3    353201-เลย จ.เลย 2011-12-01     0      0    0  0  0    0    0  ...  0
# 3  1    353201-เลย จ.เลย 2012-01-01     0      0    0  0  0    0    0  ...  0
# 4  2    353201-เลย จ.เลย 2012-02-01     0    0.2  1.2  0  0    0    0  ...  0
#
#   25 26 27   28 29 30 31 ปริมาณฝน จังหวัด
# 0  0  0  0  0.2  0  0  0      183     เลย
# 1  0  0  0  0.6  0  0  -      7.4     เลย
# 2  0  0  0    0  0  0  0      0.2     เลย
# 3  0  0  0    0  0  T  0     18.2     เลย
# 4  0  0  1    0  0  -  -      2.4     เลย
#
# [5 rows x 36 columns]

# %% [markdown]
# ##รวมตารางปริมาณฝน

# %%
rain = [RKH5, RNA5, RSA5, RNO5, RLO5] #ปริมาณฝน
allrain = pd.concat(rain)
allrain.head()
# Out:
#    ที่                     สถานี   เดือน/ปี    1     2  3  4    5    6    7  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น 2011-10-01  1.4  17.7  3  0  2.2  0.5  1.3
# 1  2    381201-ขอนแก่น จ.ขอนแก่น 2011-11-01    0     0  0  0    0    0    0
# 2  3    381201-ขอนแก่น จ.ขอนแก่น 2011-12-01    0     0  0  0    0    0    0
# 3  1    381201-ขอนแก่น จ.ขอนแก่น 2012-01-01    0     0  0  0    0    0    0
# 4  2    381201-ขอนแก่น จ.ขอนแก่น 2012-02-01    0     0  T  0    0    0    0
#
#    ... 24 25 26   27   28 29 30 31 ปริมาณฝน  จังหวัด
# 0  ...  0  T  0  0.5  1.1  0  0  0    176.8  ขอนแก่น
# 1  ...  0  0  0    0    0  0  0  -     11.8  ขอนแก่น
# 2  ...  0  0  0    0    0  0  0  0        -  ขอนแก่น
# 3  ...  0  0  0    0    0  0  T  0     38.7  ขอนแก่น
# 4  ...  0  0  0    0    0  0  -  -        T  ขอนแก่น
#
# [5 rows x 36 columns]

# %%
allrain['เดือน'] = allrain['เดือน/ปี'].dt.month #การแยกเดือนปี
allrain['ปี'] = allrain['เดือน/ปี'].dt.year
del allrain['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
allrain.head()
# Out:
#    ที่                     สถานี    1     2  3  4    5    6    7    8  ... 26  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น  1.4  17.7  3  0  2.2  0.5  1.3  0.2  ...  0
# 1  2    381201-ขอนแก่น จ.ขอนแก่น    0     0  0  0    0    0    0  3.2  ...  0
# 2  3    381201-ขอนแก่น จ.ขอนแก่น    0     0  0  0    0    0    0    0  ...  0
# 3  1    381201-ขอนแก่น จ.ขอนแก่น    0     0  0  0    0    0    0    0  ...  0
# 4  2    381201-ขอนแก่น จ.ขอนแก่น    0     0  T  0    0    0    0    0  ...  0
#
#     27   28 29 30 31 ปริมาณฝน  จังหวัด เดือน    ปี
# 0  0.5  1.1  0  0  0    176.8  ขอนแก่น    10  2011
# 1    0    0  0  0  -     11.8  ขอนแก่น    11  2011
# 2    0    0  0  0  0        -  ขอนแก่น    12  2011
# 3    0    0  0  T  0     38.7  ขอนแก่น     1  2012
# 4    0    0  0  -  -        T  ขอนแก่น     2  2012
#
# [5 rows x 37 columns]

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
r = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in allrain.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
        #  print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ปริมาณฝน -> ',row[i],row['จังหวัด'])
         r.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'ปริมาณฝน',row[i]])

rk = pd.DataFrame(r)
rk = pd.DataFrame(r, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','ปริมาณฝน'])
rk.drop(['0', '1', '2','3'], 1, inplace=True)
rk
# Out:
# <ipython-input-33-a33a279d38f8>:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   rk.drop(['0', '1', '2','3'], 1, inplace=True)
#       จังหวัด  วันที่  เดือนที่  ปีที่ ปริมาณฝน
# 0     ขอนแก่น       1        10   2011      1.4
# 1     ขอนแก่น       2        10   2011     17.7
# 2     ขอนแก่น       3        10   2011        3
# 3     ขอนแก่น       4        10   2011        0
# 4     ขอนแก่น       5        10   2011      2.2
# ...       ...     ...       ...    ...      ...
# 8520      เลย      27         2   2022        0
# 8521      เลย      28         2   2022        0
# 8522      เลย      29         2   2022        -
# 8523      เลย      30         2   2022        -
# 8524      เลย      31         2   2022        -
#
# [8525 rows x 5 columns]

# %% [markdown]
# # # อุณหภูมิจุดน้ำค้าง D

# %%
DKH6 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิจุดน้ำค้าง(เซลเซียส)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิจุดน้ำค้าง'})
DNA6 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิจุดน้ำค้าง(เซลเซียส)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิจุดน้ำค้าง'})
DSA6 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิจุดน้ำค้าง(เซลเซียส)/จ.สกล.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิจุดน้ำค้าง'})
DNO6 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิจุดน้ำค้าง(เซลเซียส)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิจุดน้ำค้าง'})
DLO6 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิจุดน้ำค้าง(เซลเซียส)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิจุดน้ำค้าง'})

DKH6['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
DNA6['จังหวัด'] = 'นครพนม'
DSA6['จังหวัด'] = 'สกลนคร'
DNO6['จังหวัด'] = 'หนองคาย'
DLO6['จังหวัด'] = 'เลย'
DLO6.head()
# Out:
#    ที่             สถานี   เดือน/ปี     1     2     3     4     5     6     7  \
# 0  1    353201-เลย จ.เลย 2011-10-01  23.6  23.5  21.9  21.9  21.8  21.6  21.7
# 1  2    353201-เลย จ.เลย 2011-11-01  20.1  19.5  19.5  19.1  19.5  20.5  20.6
# 2  3    353201-เลย จ.เลย 2011-12-01  18.0  16.6  15.0  14.6  15.3  16.7  18.9
# 3  1    353201-เลย จ.เลย 2012-01-01  16.2  16.4  17.6  18.2  15.2  16.1  17.0
# 4  2    353201-เลย จ.เลย 2012-02-01  17.8  18.8  20.7  19.1  19.5  18.2  16.4
#
#    ...    24    25    26    27    28    29    30    31  อุณหภูมิจุดน้ำค้าง  \
# 0  ...  21.5  21.2  21.0  21.6  21.3    21  20.2  20.2           21.793548
# 1  ...  17.0  16.7  17.5  18.8  19.2  19.5  19.4     -           18.953333
# 2  ...  12.8   9.7   9.4  11.0  14.9  16.2  16.2  16.5           14.735484
# 3  ...  18.7  18.5  16.9  17.6  18.5  19.2  18.2  17.4           16.851613
# 4  ...  16.3  17.1  16.7  18.7  18.6  16.9     -     -           17.310345
#
#    จังหวัด
# 0      เลย
# 1      เลย
# ...

# %% [markdown]
# ###รวมตารางอุณหภูมิจุดน้ำค้าง

# %%
tem1 = [DKH6, DNA6, DSA6, DNO6, DLO6] #อุณหภูมิจุดน้ำค้าง
alltem1 = pd.concat(tem1)
alltem1.head()
# Out:
#    ที่                     สถานี   เดือน/ปี     1     2     3     4     5  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น 2011-10-01  24.2  24.0  22.9  21.9  21.7
# 1  2    381201-ขอนแก่น จ.ขอนแก่น 2011-11-01  20.2  18.5  19.4  19.0  19.2
# 2  3    381201-ขอนแก่น จ.ขอนแก่น 2011-12-01  17.7  15.3  12.7  14.0  14.6
# 3  1    381201-ขอนแก่น จ.ขอนแก่น 2012-01-01  16.5  17.4  18.7  17.0  15.3
# 4  2    381201-ขอนแก่น จ.ขอนแก่น 2012-02-01  18.0  19.6  19.5  19.2  20.7
#
#       6     7  ...    24    25    26    27    28    29    30    31  \
# 0  21.3  21.9  ...  21.8  21.8  20.7  20.8  21.9  20.3  19.7  19.7
# 1  20.6  21.3  ...  16.7  16.7  18.3  19.2  18.9    19  18.3     -
# 2  16.6  19.1  ...  12.9   9.8   9.7  12.4  16.1  16.3  16.1  16.3
# 3  16.7  15.6  ...  19.2  19.2  16.3  19.5  19.7  19.4  18.7  16.7
# 4  20.8  19.1  ...  17.0  16.3  18.8  22.3  22.1  21.3     -     -
#
#    อุณหภูมิจุดน้ำค้าง  จังหวัด
# 0           21.903226  ขอนแก่น
# 1           18.910000  ขอนแก่น
# ...

# %%
alltem1['เดือน'] = alltem1['เดือน/ปี'].dt.month #การแยกเดือนปี
alltem1['ปี'] = alltem1['เดือน/ปี'].dt.year
del alltem1['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
alltem1.head()
# Out:
#    ที่                     สถานี     1     2     3     4     5     6     7  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น  24.2  24.0  22.9  21.9  21.7  21.3  21.9
# 1  2    381201-ขอนแก่น จ.ขอนแก่น  20.2  18.5  19.4  19.0  19.2  20.6  21.3
# 2  3    381201-ขอนแก่น จ.ขอนแก่น  17.7  15.3  12.7  14.0  14.6  16.6  19.1
# 3  1    381201-ขอนแก่น จ.ขอนแก่น  16.5  17.4  18.7  17.0  15.3  16.7  15.6
# 4  2    381201-ขอนแก่น จ.ขอนแก่น  18.0  19.6  19.5  19.2  20.7  20.8  19.1
#
#       8  ...    26    27    28    29    30    31  อุณหภูมิจุดน้ำค้าง  จังหวัด  \
# 0  23.3  ...  20.7  20.8  21.9  20.3  19.7  19.7           21.903226  ขอนแก่น
# 1  21.2  ...  18.3  19.2  18.9    19  18.3     -           18.910000  ขอนแก่น
# 2  19.1  ...   9.7  12.4  16.1  16.3  16.1  16.3           14.525806  ขอนแก่น
# 3  14.3  ...  16.3  19.5  19.7  19.4  18.7  16.7           18.058065  ขอนแก่น
# 4  19.7  ...  18.8  22.3  22.1  21.3     -     -           18.772414  ขอนแก่น
#
#    เดือน    ปี
# 0     10  2011
# ...

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
t = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in alltem1.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
        #  print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'อุณหภูมิจุดน้ำค้าง -> ',row[i],row['จังหวัด'])
         t.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'อุณหภูมิจุดน้ำค้าง',row[i]])

tk = pd.DataFrame(t)
tk = pd.DataFrame(t, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','อุณหภูมิจุดน้ำค้าง'])
tk.drop(['0', '1', '2','3'], 1, inplace=True)
tk
# Out:
# <ipython-input-37-ce7daa3bc612>:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   tk.drop(['0', '1', '2','3'], 1, inplace=True)
#       จังหวัด  วันที่  เดือนที่  ปีที่ อุณหภูมิจุดน้ำค้าง
# 0     ขอนแก่น       1        10   2011               24.2
# 1     ขอนแก่น       2        10   2011               24.0
# 2     ขอนแก่น       3        10   2011               22.9
# 3     ขอนแก่น       4        10   2011               21.9
# 4     ขอนแก่น       5        10   2011               21.7
# ...       ...     ...       ...    ...                ...
# 8365      เลย      27         2   2021               13.8
# 8366      เลย      28         2   2021               15.2
# 8367      เลย      29         2   2021                  -
# 8368      เลย      30         2   2021                  -
# 8369      เลย      31         2   2021                  -
#
# [8370 rows x 5 columns]

# %% [markdown]
# #อุณหภูมิตุ้มแห้ง DW

# %%
DWKH7 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิตุ้มแห้ง(เซลเซียส)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิตุ้ม'})
DWNA7 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิตุ้มแห้ง(เซลเซียส)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิตุ้ม'})
DWSA7 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิตุ้มแห้ง(เซลเซียส)/จ.สกล.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิตุ้ม'})
DWNO7 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิตุ้มแห้ง(เซลเซียส)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิตุ้ม'})
DWLO7 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิตุ้มแห้ง(เซลเซียส)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิตุ้ม'})

DWKH7['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
DWNA7['จังหวัด'] = 'นครพนม'
DWSA7['จังหวัด'] = 'สกลนคร'
DWNO7['จังหวัด'] = 'หนองคาย'
DWLO7['จังหวัด'] = 'เลย'
DWLO7.head()
# Out:
#    ที่             สถานี   เดือน/ปี     1     2     3     4     5     6     7  \
# 0  1    353201-เลย จ.เลย 2011-10-01  26.3  25.1  24.4  25.2  25.6  23.7  24.6
# 1  2    353201-เลย จ.เลย 2011-11-01  25.3  24.7  24.5  24.4  24.9  25.4  25.8
# 2  3    353201-เลย จ.เลย 2011-12-01  23.9  22.9  21.0  20.9  22.3  21.6  23.8
# 3  1    353201-เลย จ.เลย 2012-01-01  22.7  22.9  24.1  24.3  23.3  23.0  22.2
# 4  2    353201-เลย จ.เลย 2012-02-01  23.4  24.2  23.2  24.0  25.6  26.3  25.9
#
#    ...    24    25    26    27    28    29    30    31  อุณหภูมิตุ้ม  จังหวัด
# 0  ...  26.1  26.1  26.2  25.9  25.6  26.3  25.6  24.8          25.6      เลย
# 1  ...  23.6  22.9  23.3  24.5  24.1  25.5  25.5     -          24.4      เลย
# 2  ...  19.8  16.6  16.4  17.6  21.1  22.7  22.6  23.2          21.1      เลย
# 3  ...  24.4  23.5  22.8  23.4  24.9  25.5  23.5  23.5          23.3      เลย
# 4  ...  25.9  26.9  26.8  26.5  26.7  26.7     -     -          25.4      เลย
#
# [5 rows x 36 columns]

# %% [markdown]
# ##รวมตารางอุณหภูมิตุ้มแห้ง

# %%
tem2 = [DWKH7, DWNA7, DWSA7, DWNO7, DWLO7] #อุณหภูมิตุ้มแห้ง
alltem2 = pd.concat(tem2)
alltem2.head()
# Out:
#    ที่                     สถานี   เดือน/ปี     1     2     3     4     5  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น 2011-10-01  27.6  25.6  25.6  25.8  24.3
# 1  2    381201-ขอนแก่น จ.ขอนแก่น 2011-11-01  26.3  26.3  26.3  26.6  26.8
# 2  3    381201-ขอนแก่น จ.ขอนแก่น 2011-12-01  25.4  23.9  21.3  22.3  23.0
# 3  1    381201-ขอนแก่น จ.ขอนแก่น 2012-01-01  23.8  24.5  25.0  24.8  22.8
# 4  2    381201-ขอนแก่น จ.ขอนแก่น 2012-02-01  23.9  25.4  25.3  24.8  27.2
#
#       6     7  ...    24    25    26    27    28    29    30    31  \
# 0  24.0  25.1  ...  27.6  27.4  27.2  27.3  26.9  26.3  25.8  26.2
# 1  27.5  27.9  ...  23.9  24.4  25.5  26.1  26.2    26    26     -
# 2  25.6  25.4  ...  21.1  18.3  18.3  20.4  23.5  23.7  24.2  24.1
# 3  23.4  23.1  ...  24.4  24.1  22.1  24.6  26.3  25.6  25.3    23
# 4  28.2  28.3  ...  29.1  29.6  29.2  28.2  27.5  28.5     -     -
#
#    อุณหภูมิตุ้ม  จังหวัด
# 0          26.2  ขอนแก่น
# 1          25.8  ขอนแก่น
# 2          22.4  ขอนแก่น
# ...

# %%
alltem2['เดือน'] = alltem2['เดือน/ปี'].dt.month #การแยกเดือนปี
alltem2['ปี'] = alltem2['เดือน/ปี'].dt.year
del alltem2['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
alltem2.head()
# Out:
#    ที่                     สถานี     1     2     3     4     5     6     7  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น  27.6  25.6  25.6  25.8  24.3  24.0  25.1
# 1  2    381201-ขอนแก่น จ.ขอนแก่น  26.3  26.3  26.3  26.6  26.8  27.5  27.9
# 2  3    381201-ขอนแก่น จ.ขอนแก่น  25.4  23.9  21.3  22.3  23.0  25.6  25.4
# 3  1    381201-ขอนแก่น จ.ขอนแก่น  23.8  24.5  25.0  24.8  22.8  23.4  23.1
# 4  2    381201-ขอนแก่น จ.ขอนแก่น  23.9  25.4  25.3  24.8  27.2  28.2  28.3
#
#       8  ...    26    27    28    29    30    31  อุณหภูมิตุ้ม  จังหวัด  \
# 0  27.0  ...  27.2  27.3  26.9  26.3  25.8  26.2          26.2  ขอนแก่น
# 1  28.0  ...  25.5  26.1  26.2    26    26     -          25.8  ขอนแก่น
# 2  25.7  ...  18.3  20.4  23.5  23.7  24.2  24.1          22.4  ขอนแก่น
# 3  22.6  ...  22.1  24.6  26.3  25.6  25.3    23          24.4  ขอนแก่น
# 4  26.4  ...  29.2  28.2  27.5  28.5     -     -          26.5  ขอนแก่น
#
#    เดือน    ปี
# 0     10  2011
# 1     11  2011
# 2     12  2011
# ...

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
t2 = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in alltem2.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
        #  print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'อุณหภูมิตุ้ม -> ',row[i],row['จังหวัด'])
         t2.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'อุณหภูมิตุ้ม',row[i]])

t2k = pd.DataFrame(t2)
t2k = pd.DataFrame(t2, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','อุณหภูมิตุ้ม'])
t2k.drop(['0', '1', '2','3'], 1, inplace=True)
t2k
# Out:
# <ipython-input-41-b1b75e6884c2>:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t2k.drop(['0', '1', '2','3'], 1, inplace=True)
#       จังหวัด  วันที่  เดือนที่  ปีที่ อุณหภูมิตุ้ม
# 0     ขอนแก่น       1        10   2011         27.6
# 1     ขอนแก่น       2        10   2011         25.6
# 2     ขอนแก่น       3        10   2011         25.6
# 3     ขอนแก่น       4        10   2011         25.8
# 4     ขอนแก่น       5        10   2011         24.3
# ...       ...     ...       ...    ...          ...
# 8365      เลย      27         2   2021         25.2
# 8366      เลย      28         2   2021         25.6
# 8367      เลย      29         2   2021            -
# 8368      เลย      30         2   2021            -
# 8369      เลย      31         2   2021            -
#
# [8370 rows x 5 columns]

# %% [markdown]
# #อุณหภูมิต่ำสุด L

# %%
LKH8 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิต่ำสุด(เซลเซียส)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิต่ำสุด'})
LNA8 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิต่ำสุด(เซลเซียส)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิต่ำสุด'})
LSA8 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิต่ำสุด(เซลเซียส)/จ.สกล.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิต่ำสุด'})
LNO8 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิต่ำสุด(เซลเซียส)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิต่ำสุด'})
LLO8 = pd.read_excel('/content/drive/MyDrive/DPDM/อุตุ/อุณหภูมิต่ำสุด(เซลเซียส)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4).rename(columns={'Unnamed: 0' : 'ที่', 'Unnamed: 1' : 'สถานี', 'Unnamed: 2' : 'เดือน/ปี', 'Unnamed: 34' : 'อุณหภูมิต่ำสุด'})

LKH8['จังหวัด'] = 'ขอนแก่น' #เพิ่มคอลัมน์จังหวัด
LNA8['จังหวัด'] = 'นครพนม'
LSA8['จังหวัด'] = 'สกลนคร'
LNO8['จังหวัด'] = 'หนองคาย'
LLO8['จังหวัด'] = 'เลย'
LLO8.head()
# Out:
#    ที่             สถานี   เดือน/ปี     1     2     3     4     5     6     7  \
# 0  1    353201-เลย จ.เลย 2011-10-01  23.5  24.3  22.5  23.0  22.7  23.2  21.0
# 1  2    353201-เลย จ.เลย 2011-11-01  20.7  19.9  19.1  19.0  19.5  19.8  20.5
# 2  3    353201-เลย จ.เลย 2011-12-01    18  19.6  15.5  14.4  17.1  15.5  17.2
# 3  1    353201-เลย จ.เลย 2012-01-01    16  16.1  17.9  20.9  19.6  16.8  17.0
# 4  2    353201-เลย จ.เลย 2012-02-01    19  19.0  21.7  20.2  18.9  18.0  16.5
#
#    ...    24    25    26    27    28    29    30    31  อุณหภูมิต่ำสุด  \
# 0  ...  21.5  21.6  21.8  21.5  21.2  21.8    21  20.5            22.2
# 1  ...  18.6  16.9  17.0  19.2  19.3  20.3  19.5     -            19.2
# 2  ...  15.0  11.1   9.9  10.0    13  15.9  16.5  16.4            15.2
# 3  ...  21.0  19.0  18.9  16.8    19    21  21.3  20.5            18.2
# 4  ...  16.5  18.5  18.5  20.0  20.1  18.4     -     -            18.6
#
#    จังหวัด
# 0      เลย
# 1      เลย
# 2      เลย
# 3      เลย
# ...

# %% [markdown]
# ##รวมตารางอุณหภูมิต่ำสุด

# %%
tem3 = [LKH8, LNA8, LSA8, LNO8, LLO8] #อุณหภูมิต่ำสุด
alltem3 = pd.concat(tem3)
alltem3.head()
# Out:
#    ที่                     สถานี   เดือน/ปี     1     2     3     4     5  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น 2011-10-01  24.8  23.0  22.1  22.8  23.1
# 1  2    381201-ขอนแก่น จ.ขอนแก่น 2011-11-01  20.7  20.4  20.5  20.9  20.6
# 2  3    381201-ขอนแก่น จ.ขอนแก่น 2011-12-01  19.3  18.9  15.4  15.6  16.3
# 3  1    381201-ขอนแก่น จ.ขอนแก่น 2012-01-01  17.7  19.6  20.4  20.7  16.8
# 4  2    381201-ขอนแก่น จ.ขอนแก่น 2012-02-01  19.4  20.5  20.9  20.9  21.5
#
#       6     7  ...    24    25    26    27    28    29    30    31  \
# 0  21.7  22.0  ...    22  22.7  21.6  21.7  22.4  21.7  20.2  21.1
# 1  22.2  23.8  ...  18.5  18.4  18.9  20.2  20.1  20.2  19.8     -
# 2  20.2  20.8  ...  16.5  12.1  11.6  13.2  16.5  16.7  18.4    17
# 3  16.9  16.8  ...  18.6  19.4  16.2  17.5  21.6  20.8  21.6  20.1
# 4  21.1  20.7  ...  21.3  21.1  21.3  23.4    22  22.2     -     -
#
#   อุณหภูมิต่ำสุด  จังหวัด
# 0           22.4  ขอนแก่น
# 1           20.3  ขอนแก่น
# 2           16.4  ขอนแก่น
# ...

# %%
alltem3['เดือน'] = alltem3['เดือน/ปี'].dt.month #การแยกเดือนปี
alltem3['ปี'] = alltem3['เดือน/ปี'].dt.year
del alltem3['เดือน/ปี'] #ลบคอมลัมบ์ เดือน/ปี
alltem3.head()
# Out:
#    ที่                     สถานี     1     2     3     4     5     6     7  \
# 0  1    381201-ขอนแก่น จ.ขอนแก่น  24.8  23.0  22.1  22.8  23.1  21.7  22.0
# 1  2    381201-ขอนแก่น จ.ขอนแก่น  20.7  20.4  20.5  20.9  20.6  22.2  23.8
# 2  3    381201-ขอนแก่น จ.ขอนแก่น  19.3  18.9  15.4  15.6  16.3  20.2  20.8
# 3  1    381201-ขอนแก่น จ.ขอนแก่น  17.7  19.6  20.4  20.7  16.8  16.9  16.8
# 4  2    381201-ขอนแก่น จ.ขอนแก่น  19.4  20.5  20.9  20.9  21.5  21.1  20.7
#
#       8  ...    26    27    28    29    30    31  อุณหภูมิต่ำสุด  จังหวัด  \
# 0  23.2  ...  21.6  21.7  22.4  21.7  20.2  21.1            22.4  ขอนแก่น
# 1  22.4  ...  18.9  20.2  20.1  20.2  19.8     -            20.3  ขอนแก่น
# 2  21.0  ...  11.6  13.2  16.5  16.7  18.4    17            16.4  ขอนแก่น
# 3  15.5  ...  16.2  17.5  21.6  20.8  21.6  20.1            19.4  ขอนแก่น
# 4  20.4  ...  21.3  23.4    22  22.2     -     -            20.1  ขอนแก่น
#
#   เดือน    ปี
# 0    10  2011
# 1    11  2011
# 2    12  2011
# ...

# %% [markdown]
# ##  LOOP ทุกจังหวัด

# %%
t3 = list() #สร้างดิกชินารี่เข้ามาเก็บ
for index, row in alltem3.iterrows():
  for i in range(1,32): #เพราะเราจะเอาคอลัมน์ที่มีชื่อว่า 1
        #  print(f'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'อุณหภูมิต่ำสุด-> ',row[i],row['จังหวัด'])
         t3.append([row['จังหวัด'],'วันที่ ',i,'เดือนที่ ',row['เดือน'],' ปีที่ ', row['ปี'],'อุณหภูมิต่ำสุด',row[i]])

t3k = pd.DataFrame(t3)
t3k = pd.DataFrame(t3, columns=['จังหวัด','0','วันที่','1','เดือนที่','2','ปีที่','3','อุณหภูมิต่ำสุด'])
t3k.drop(['0', '1', '2','3'], 1, inplace=True)
t3k
# Out:
# <ipython-input-45-7ba0fdaa43d6>:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   t3k.drop(['0', '1', '2','3'], 1, inplace=True)
#       จังหวัด  วันที่  เดือนที่  ปีที่ อุณหภูมิต่ำสุด
# 0     ขอนแก่น       1        10   2011           24.8
# 1     ขอนแก่น       2        10   2011           23.0
# 2     ขอนแก่น       3        10   2011           22.1
# 3     ขอนแก่น       4        10   2011           22.8
# 4     ขอนแก่น       5        10   2011           23.1
# ...       ...     ...       ...    ...            ...
# 8520      เลย      27         2   2022           15.0
# 8521      เลย      28         2   2022           17.6
# 8522      เลย      29         2   2022              -
# 8523      เลย      30         2   2022              -
# 8524      เลย      31         2   2022              -
#
# [8525 rows x 5 columns]

# %% [markdown]
# # merge ทั้งหมด

# %%
merge_a = pk.merge(hk, how ='inner', left_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'],right_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'])
merge_b = merge_a.merge(wk, how ='inner', left_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'],right_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'])
merge_c = merge_b.merge(ck, how ='inner', left_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'],right_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'])
merge_d = merge_c.merge(rk, how ='inner', left_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'],right_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'])
merge_e = merge_d.merge(tk, how ='inner', left_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'],right_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'])
merge_f = merge_e.merge(t2k, how ='inner', left_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'],right_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'])
mergefinal = merge_f.merge(t3k, how ='inner', left_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'],right_on=['จังหวัด', 'วันที่',	'เดือนที่',	'ปีที่'])
mergefinal
# Out:
#       จังหวัด  วันที่  เดือนที่  ปีที่   ความกด ความชื้นสัมพัทธ์ ความเร็วลม  \
# 0     ขอนแก่น       1        10   2011  1005.47               83          3
# 1     ขอนแก่น       2        10   2011  1006.65               92          2
# 2     ขอนแก่น       3        10   2011  1007.49               86          3
# 3     ขอนแก่น       4        10   2011  1008.28               80          2
# 4     ขอนแก่น       5        10   2011  1009.88               86          2
# ...       ...     ...       ...    ...      ...              ...        ...
# 8365      เลย      27         2   2021  1005.76               56          1
# 8366      เลย      28         2   2021  1008.21               58          1
# 8367      เลย      29         2   2021        -                -          -
# 8368      เลย      30         2   2021        -                -          -
# 8369      เลย      31         2   2021        -                -          -
#
# ...

# %%
mergefinal.head()
# Out:
#    จังหวัด  วันที่  เดือนที่  ปีที่   ความกด ความชื้นสัมพัทธ์ ความเร็วลม  \
# 0  ขอนแก่น       1        10   2011  1005.47               83          3
# 1  ขอนแก่น       2        10   2011  1006.65               92          2
# 2  ขอนแก่น       3        10   2011  1007.49               86          3
# 3  ขอนแก่น       4        10   2011  1008.28               80          2
# 4  ขอนแก่น       5        10   2011  1009.88               86          2
#
#   จำนวนเมฆ ปริมาณฝน อุณหภูมิจุดน้ำค้าง อุณหภูมิตุ้ม อุณหภูมิต่ำสุด
# 0        9      1.4               24.2         27.6           24.8
# 1       10     17.7               24.0         25.6           23.0
# 2       10        3               22.9         25.6           22.1
# 3        8        0               21.9         25.8           22.8
# 4       10      2.2               21.7         24.3           23.1

# %% [markdown]
# # ลบวันที่เกินออก

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
cols=["ปีที่","เดือนที่","วันที่"]
mergefinal['date'] = mergefinal[cols].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")
mergefinal['date'] = pd.to_datetime(mergefinal['date'], errors='coerce')
mergefinal = mergefinal.dropna(subset=['date'])
mergefinal
# Out:
#       จังหวัด  วันที่  เดือนที่  ปีที่   ความกด ความชื้นสัมพัทธ์ ความเร็วลม  \
# 0     ขอนแก่น       1        10   2011  1005.47               83          3
# 1     ขอนแก่น       2        10   2011  1006.65               92          2
# 2     ขอนแก่น       3        10   2011  1007.49               86          3
# 3     ขอนแก่น       4        10   2011  1008.28               80          2
# 4     ขอนแก่น       5        10   2011  1009.88               86          2
# ...       ...     ...       ...    ...      ...              ...        ...
# 8362      เลย      24         2   2021  1008.39               69          1
# 8363      เลย      25         2   2021  1006.05               61          1
# 8364      เลย      26         2   2021  1004.86               55          2
# 8365      เลย      27         2   2021  1005.76               56          1
# 8366      เลย      28         2   2021  1008.21               58          1
#
# ...
