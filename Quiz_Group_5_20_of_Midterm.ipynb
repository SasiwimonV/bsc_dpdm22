# %% [markdown]
# <a href="https://colab.research.google.com/github/SasiwimonV/bsc_dpdm22/blob/main/Quiz_Group_5_20_of_Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# เตรียมข้อมูลของ กรม อุตุ ([link](https://drive.google.com/drive/folders/1k6tJcTTv2bKmFz6A5oOWi-sAeTVIQpG4?usp=sharing)) ให้อยู่ในรูปแบบ ตารางด้านล่าง เพื่อเตรียมข้อมูลสำหรับสร้าง Model ทำนาย อุณภูมิต่ำสุดของวันจากค่าอื่นๆ

# %% [markdown]
# ![Screen Shot 2566-01-11 at 09.36.17.png](data:image/png;base64,...)

# %% [markdown]
# column เดือน-ปี สามารถยุบรวมเป็น 1 column ได้

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
skkc = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความเร็วลม/สำเนาของ จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=3)
skkc.head()
# Out:
#    ที่                  สถานี   เดือน/ปี  วันที่  Unnamed: 4 Unnamed: 5  \
# 0  NaN                    NaN        NaT       1           2          3
# 1  1    353301-เลย สกษ. จ.เลย 2011-10-01       3           2          3
# 2  2    353301-เลย สกษ. จ.เลย 2011-11-01       4           5          3
# 3  3    353301-เลย สกษ. จ.เลย 2011-12-01       3           4          4
# 4  1    353301-เลย สกษ. จ.เลย 2012-01-01       4           2          1
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 25  \
# 0           4           5           6           7  ...           23
# 1           2           2           3           4  ...            2
# 2           3           5           2           3  ...            7
# 3           4           4           4           4  ...            5
# 4           4           4           2           4  ...            3
#
#    Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  Unnamed: 30  \
# ...

# %%
skkc = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด/สำเนาของ จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=3)
skkc.head()
# Out:
#    ที่                     สถานี   เดือน/ปี   วันที่  Unnamed: 4  Unnamed: 5  \
# 0  NaN                       NaN        NaT     1.00        2.00        3.00
# 1  1    352201-หนองคาย จ.หนองคาย 2011-10-01  1005.47     1006.65     1007.49
# 2  2    352201-หนองคาย จ.หนองคาย 2011-11-01  1011.79     1010.83     1010.74
# 3  3    352201-หนองคาย จ.หนองคาย 2011-12-01  1011.43     1012.57     1012.28
# 4  1    352201-หนองคาย จ.หนองคาย 2012-01-01  1015.67     1014.11     1012.91
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 25  \
# 0        4.00        5.00        6.00        7.00  ...        23.00
# 1     1008.28     1009.88     1011.36     1011.17  ...      1010.76
# 2     1010.71     1010.09     1009.24     1008.03  ...      1014.07
# 3     1012.97     1013.09     1012.03     1012.05  ...      1012.88
# 4     1014.06     1015.51     1015.88     1017.72  ...      1010.91
#
#    Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  Unnamed: 30  \
# ...
