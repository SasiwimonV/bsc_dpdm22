# %% [markdown]
# <a href="https://colab.research.google.com/github/SasiwimonV/bsc_dpdm22/blob/main/%5Bdataset1%5D_property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
home = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน',skiprows=0) #เลือก ชีท บ้าน
home.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %% [markdown]
# #สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %% [markdown]
# #บ้าน

# %%
est1 = home[home['ID ผู้ประเมิน']==1]
est1 #100*14
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  6.100000e+01         1.000000e+02         0.0
# mean             1.0  4.004721e+06         3.938500e+06         NaN
# std              0.0  3.039496e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.500000e+06         2.775000e+06         NaN
# 50%              1.0  3.630000e+06         3.600000e+06         NaN
# 75%              1.0  4.774000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
est1[est1['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count()
# Out:
# ID ผู้ประเมิน                     100
# post id                           100
# property_type                     100
# ความมั่นใจในการเมินราคาทรัพย์     100
# ราคาทรัพย์                         61
# ประเมินราคาซื้อ-ขาย               100
# ปัจจัยในการประเมินราคาซื้อ-ขาย    100
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    100
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         0
# Unnamed: 13                         1
# dtype: int64

# %%
est1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='1 ขายไม่ได้แน่นอน'].count #มี 1 คน
# Out:
# <bound method DataFrame.count of     ID ผู้ประเมิน                               post id property_type  \
# 90              1  https://nayoo.co/khonkaen/posts/5978    บ้านเดี่ยว
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 90                        มั่นใจ  20949000.0           16000000.0
#
#    ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 90       3,000-30,000 บาท/ตารางวา                        NaN
#
#        ให้คะแนนทรัพย์  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 90  1 ขายไม่ได้แน่นอน         NaN          NaN          NaN          NaN
#
#     Unnamed: 13
# 90          NaN  >

# %%
est1[est1['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี'].count()
# Out:
# ID ผู้ประเมิน                     54
# post id                           54
# property_type                     54
# ความมั่นใจในการเมินราคาทรัพย์     54
# ราคาทรัพย์                        28
# ประเมินราคาซื้อ-ขาย               54
# ปัจจัยในการประเมินราคาซื้อ-ขาย    54
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    54
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน'].count()
# Out:
# ID ผู้ประเมิน                     43
# post id                           43
# property_type                     43
# ความมั่นใจในการเมินราคาทรัพย์     43
# ราคาทรัพย์                        30
# ประเมินราคาซื้อ-ขาย               43
# ปัจจัยในการประเมินราคาซื้อ-ขาย    43
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    43
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        1
# dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน'].count()
# Out:
# ID ผู้ประเมิน                     2
# post id                           2
# property_type                     2
# ความมั่นใจในการเมินราคาทรัพย์     2
# ราคาทรัพย์                        2
# ประเมินราคาซื้อ-ขาย               2
# ปัจจัยในการประเมินราคาซื้อ-ขาย    2
# เหตุผลไม่มั่นใจราคาประเมิน        0
# ให้คะแนนทรัพย์                    2
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %%
est1[est1['ให้คะแนนทรัพย์']=='5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน'].count()
# Out:
# ID ผู้ประเมิน                     0
# post id                           0
# property_type                     0
# ความมั่นใจในการเมินราคาทรัพย์     0
# ราคาทรัพย์                        0
# ประเมินราคาซื้อ-ขาย               0
# ปัจจัยในการประเมินราคาซื้อ-ขาย    0
# เหตุผลไม่มั่นใจราคาประเมิน        0
# ให้คะแนนทรัพย์                    0
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %%
est2 = home[home['ID ผู้ประเมิน']==2]
est2 #90*14
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est2[est2['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count()
# Out:
# ID ผู้ประเมิน                     89
# post id                           89
# property_type                     89
# ความมั่นใจในการเมินราคาทรัพย์     89
# ราคาทรัพย์                        61
# ประเมินราคาซื้อ-ขาย               89
# ปัจจัยในการประเมินราคาซื้อ-ขาย    89
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    89
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
est2[est2['ความมั่นใจในการเมินราคาทรัพย์']=='ไม่มั่นใจ'].count()
# Out:
# ID ผู้ประเมิน                     1
# post id                           1
# property_type                     1
# ความมั่นใจในการเมินราคาทรัพย์     1
# ราคาทรัพย์                        0
# ประเมินราคาซื้อ-ขาย               0
# ปัจจัยในการประเมินราคาซื้อ-ขาย    0
# เหตุผลไม่มั่นใจราคาประเมิน        1
# ให้คะแนนทรัพย์                    0
# Unnamed: 9                        0
# Unnamed: 10                       0
# Unnamed: 11                       0
# Unnamed: 12                       0
# Unnamed: 13                       0
# dtype: int64

# %%
est2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##Map Data

# %%
est2['ประเมิน1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2
# Out:
# <ipython-input-18-5722fc6584f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2['ประเมิน1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# ...

# %%
est2 = est2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
est2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์   ประเมิน2  \
# ...

# %%
table = est2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]

# %%
table = table.dropna(subset=['ราคาทรัพย์']) # row หายไป 29 row เพราะ มีค่า Nan เราไม่ fillna(0) เพราะ เวลาแทนสูตรจะหาไม่ได้

# %%
table
# Out:
#                                  post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3     https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5    https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7    https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9    https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                   ...         ...        ...        ...
# 113   https://nayoo.co/khonkaen/posts/23   5230000.0  5000000.0  5000000.0
# 115   https://nayoo.co/khonkaen/posts/28   1750000.0  1600000.0  1900000.0
# 187   https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188   https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189  https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [61 rows x 4 columns]

# %% [markdown]
# ##Check Data

# %%
table.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
import numpy as np

# %% [markdown]
# ##function ตรวจสอบค่าที่เติม 0 ผิด

# %%
def checkvalue(a, b):
  return max(a/b, b/a)

# %%
checkvalue(10,1200)
# Out:
# 120.0

# %%
table.head()
# Out:
#                                post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1   https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3   https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5  https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7  https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9  https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0

# %% [markdown]
# ##สร้าง column ใหม่ ลงในตาราง table(บ้าน) โดย ค่าใน columnใหม่ คือค่า จาก function checkvalue
# (ราคาตั้งขาย,ราคาประเมิน1)

# %%
link = 'https://docs.google.com/spreadsheets/d/1zNhL_S76z2RUxfkm6yj6OCiasPkzxq75bk_ScB3JxCE/export?format=xlsx'
land = pd.read_excel(link,sheet_name='บ้าน')
land
# Out:
#       ID ผู้ประเมิน                               post id property_type  \
# 0                 1    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                 2    https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                 1    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                 2    https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                 1   https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ...             ...                                   ...           ...
# 1215              1  https://nayoo.co/khonkaen/posts/6257    บ้านเดี่ยว
# 1216              2  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1217              1  https://nayoo.co/khonkaen/posts/6258    บ้านเดี่ยว
# 1218              2  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
# 1219              1  https://nayoo.co/khonkaen/posts/6260    บ้านเดี่ยว
#
#      ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
#table['Check'] = table.apply(lambda x: checkvalue(x.ราคาทรัพย์, x.ประเมิน1), axis=1)

# %%
#table['Check2'] = table.apply(lambda x: checkvalue(x.ราคาทรัพย์, x.ประเมิน2), axis=1)

# %% [markdown]
# ## For loop

# %%
check1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว่้ใน list
check2 = list()
for row in table.iterrows():
    check1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    check2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
check1
check2
# แต่ละ row ใน table จะทำใช้ function 'checkvalue' เพื่อหาค่าแล้วเพิ่มใน check1
# Out:
# [1.0,
#  1.0833333333333333,
#  1.5254237288135593,
#  1.1891891891891893,
#  1.1,
#  1.0314685314685315,
#  1.050420168067227,
#  1.0416666666666667,
#  1.1403333333333334,
#  1.0175,
#  1.0476190476190477,
#  1.03125,
#  1.0214285714285714,
#  1.0607142857142857,
#  1.025,
#  1.0607142857142857,
#  1.0847222222222221,
#  1.0371428571428571,
#  1.0,
#  1.125,
#  1.1049723756906078,
#  1.1904761904761905,
#  1.0888888888888888,
#  1.0054461667364893,
#  1.0425531914893618,
#  1.125,
#  1.0434782608695652,
#  1.0364145658263306,
#  1.0,
#  1.0324483775811208,
#  1.04,
#  1.2,
#  1.04,
#  1.1318181818181818,
#  1.0,
#  1.045,
#  1.0526315789473684,
#  3.3333333333333335,
#  1.0227272727272727,
#  1.04,
#  1.08,
#  1.2903225806451613,
#  1.1219512195121952,
#  1.125,
#  1.2195121951219512,
#  1.2322941176470588,
#  1.0755555555555556,
#  1.1366666666666667,
#  1.0736196319018405,
#  1.1,
#  1.048951048951049,
#  1.1111111111111112,
#  1.045,
#  1.0666666666666667,
# ...

# %%
table['Check1'] = check1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
table['Check2'] = check2
table
# Out:
#                                  post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1     https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3     https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5    https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7    https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9    https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                   ...         ...        ...        ...
# 113   https://nayoo.co/khonkaen/posts/23   5230000.0  5000000.0  5000000.0
# 115   https://nayoo.co/khonkaen/posts/28   1750000.0  1600000.0  1900000.0
# 187   https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188   https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189  https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
#        Check1    Check2
# 1    1.080000  1.000000
# ...

# %%
table = table.sort_values(by=['Check1'],ascending=False) # Clean
table
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 187    https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 75      https://nayoo.co/khonkaen/posts/1    390000.0   600000.0  1300000.0
# 101  https://nayoo.co/khonkaen/posts/6010   2860000.0  4200000.0  3000000.0
# 111  https://nayoo.co/khonkaen/posts/6045   2915000.0  2000000.0  2000000.0
# 67   https://nayoo.co/khonkaen/posts/2244   2490000.0  1800000.0  2200000.0
# ..                                    ...         ...        ...        ...
# 63   https://nayoo.co/khonkaen/posts/2033   1200000.0  1200000.0  1000000.0
# 65   https://nayoo.co/khonkaen/posts/2143   5200000.0  5200000.0  5000000.0
# 43   https://nayoo.co/khonkaen/posts/1128   4200000.0  4200000.0  5000000.0
# 51   https://nayoo.co/khonkaen/posts/1149   4000000.0  4000000.0  4500000.0
# 87   https://nayoo.co/khonkaen/posts/3905   1200000.0  1200000.0  1350000.0
#
#        Check1    Check2
# 187  1.800000  1.250000
# ...

# %%
table = table.sort_values(by=['Check2'],ascending=False)#Clean
table
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 75      https://nayoo.co/khonkaen/posts/1    390000.0   600000.0  1300000.0
# 5     https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 111  https://nayoo.co/khonkaen/posts/6045   2915000.0  2000000.0  2000000.0
# 83   https://nayoo.co/khonkaen/posts/3721   3100000.0  3500000.0  4000000.0
# 187    https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# ..                                    ...         ...        ...        ...
# 47   https://nayoo.co/khonkaen/posts/1135   4774000.0  5200000.0  4800000.0
# 57   https://nayoo.co/khonkaen/posts/1895   1200000.0  1500000.0  1200000.0
# 69   https://nayoo.co/khonkaen/posts/2262   3200000.0  3300000.0  3200000.0
# 37    https://nayoo.co/khonkaen/posts/760   1800000.0  1700000.0  1800000.0
# 1      https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
#
#        Check1    Check2
# 75   1.538462  3.333333
# ...

# %% [markdown]
# ###def function mape
# - ค่าเกิน 9,10 ก็ลบ ศูนย์ ถ้าเกิน 2 คนประเมินว่าแบบนั้นเลย

# %%
def mape(y_test, pred):
    y_test, pred = np.array(y_test), np.array(pred)
    mape = np.mean(np.abs((y_test - pred) / y_test))
    return mape

# %%
#ใช้คอลัมน์ ประเมิน 1 ,ประเมิน 2 ในการคำนวณ
#คอลัมน์ Check1,2 ไว้เช็คว่าค่าพุ่งเกินไหม
table1= table['ประเมิน1']
table2= table['ประเมิน2']
table3= table['ราคาทรัพย์']

# %%
mapetable = mape(table1, table2)
mapetable # ค่า mape ของผู้ประเมิน1 กับผู้ประเมิน 2
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetable)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.14843936292700438

# %%
mapetable2 = mape(table1, table3)
mapetable2 # ค่า mape ของผู้ประเมิน1 กับ ราคาทรัพย์
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetable2)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.13745423849059654

# %%
mapetable3 = mape(table2, table3)
mapetable3
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetable3)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.09514388806852346

# %% [markdown]
# #ที่ดิน

# %%
land = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน',skiprows=0) #เลือก ชีท ที่ดิน
land.head()
# Out:
#    ID ผู้ประเมิน                               post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1              2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2              4  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3              1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4              2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2800000.0            1800000.0
# 1                        มั่นใจ   2800000.0            2000000.0
# 2                        มั่นใจ   2800000.0            3000000.0
# 3                        มั่นใจ  14900000.0            8000000.0
# 4                        มั่นใจ  14900000.0           12000000.0
#
#             ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                             8,000-25,000                        NaN
# ...

# %%
land.describe() #มี210 row 
#ราคาทรัพย์ max 90 ล้าน ถูกสุด 8.5 แสน ราคาทรัพย์เฉลี่ย 11 ล้าน
#ประเมินราคา max 250 ล้าน min 5 แสน เฉลี่ย 10 ล้าน
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count     210.000000  9.000000e+01         2.070000e+02   27.000000
# mean        1.619048  1.120359e+07         1.000266e+07    2.481481
# std         0.723904  1.900198e+07         2.511594e+07    0.509175
# min         1.000000  8.500000e+05         5.000000e+05    2.000000
# 25%         1.000000  2.225000e+06         1.800000e+06    2.000000
# 50%         2.000000  4.500000e+06         3.500000e+06    2.000000
# 75%         2.000000  1.207500e+07         1.000000e+07    3.000000
# max         4.000000  9.000000e+07         2.500000e+08    3.000000
#
#        Unnamed: 11  Unnamed: 12
# count          0.0          1.0
# mean           NaN        100.0
# std            NaN          NaN
# min            NaN        100.0
# 25%            NaN        100.0
# 50%            NaN        100.0
# 75%            NaN        100.0
# max            NaN        100.0

# %%
land[land['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count() # มั่นใจ 207 ไม่มั่นใจ 3
# Out:
# ID ผู้ประเมิน                     207
# post id                           207
# property_type                     207
# ความมั่นใจในการเมินราคาทรัพย์     207
# ราคาทรัพย์                         87
# ประเมินราคาซื้อ-ขาย               207
# ปัจจัยในการประเมินราคาซื้อ-ขาย    207
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    207
# Unnamed: 9                         27
# Unnamed: 10                        27
# Unnamed: 11                         0
# Unnamed: 12                         1
# dtype: int64

# %%
land['ID ผู้ประเมิน'].value_counts() #มี210 row ID[1] = 100 , ID[2] = 100, ID[4] = 10 -> ไม่ใช้ 4
# Out:
# 1    100
# 2    100
# 4     10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
land1 = land[land['ID ผู้ประเมิน']==1]
land1.head()
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 0               1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3               1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 6               1  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 9               1  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 12              1  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                         มั่นใจ   2800000.0            1800000.0
# 3                         มั่นใจ  14900000.0            8000000.0
# 6                         มั่นใจ  90000000.0           18000000.0
# 9                         มั่นใจ  65000000.0           35000000.0
# 12                        มั่นใจ   3000000.0            2200000.0
#
#    ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                    8,000-25,000                        NaN
# ...

# %%
land2 = land[land['ID ผู้ประเมิน']==2]
land2.head()
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 1               2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4               2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7               2  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10              2  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13              2  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                         มั่นใจ   2800000.0            2000000.0
# 4                         มั่นใจ  14900000.0           12000000.0
# 7                         มั่นใจ  90000000.0           70000000.0
# 10                        มั่นใจ  65000000.0           60000000.0
# 13                        มั่นใจ   3000000.0            2500000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1     ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# ...

# %% [markdown]
# ## Map data

# %%
land2['ประเมิน1'] = land2['post id'].map(land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
land2
# Out:
# <ipython-input-46-f6fe25813445>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   land2['ประเมิน1'] = land2['post id'].map(land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# ...

# %%
tableland = land2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tableland
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์    ประเมิน2  \
# ...

# %% [markdown]
# ##Check Data

# %%
tableland.isnull().any()
# Out:
# ID ผู้ประเมิน                     False
# post id                           False
# property_type                     False
# ความมั่นใจในการเมินราคาทรัพย์     False
# ราคาทรัพย์                         True
# ประเมิน2                          False
# ปัจจัยในการประเมินราคาซื้อ-ขาย    False
# เหตุผลไม่มั่นใจราคาประเมิน         True
# ให้คะแนนทรัพย์                    False
# Unnamed: 9                         True
# Unnamed: 10                        True
# Unnamed: 11                        True
# Unnamed: 12                        True
# ประเมิน1                          False
# dtype: bool

# %%
tableland0 = tableland[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']] # ไม่เอาประเมิน 4
tableland0
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/1033   2800000.0   1800000.0   2000000.0
# 4     https://nayoo.co/khonkaen/posts/1711  14900000.0   8000000.0  12000000.0
# 7     https://nayoo.co/khonkaen/posts/1726  90000000.0  18000000.0  70000000.0
# 10    https://nayoo.co/khonkaen/posts/1732  65000000.0  35000000.0  60000000.0
# 13    https://nayoo.co/khonkaen/posts/1866   3000000.0   2200000.0   2500000.0
# ..                                     ...         ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539         NaN   4000000.0   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072         NaN    500000.0    750000.0
# 204  https://nayoo.co/khonkaen/posts/17093         NaN   2000000.0   2500000.0
# 206  https://nayoo.co/khonkaen/posts/17112         NaN   1500000.0   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145         NaN   2500000.0   2800000.0
#
# [100 rows x 4 columns]

# %%
tableland0.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์     True
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
tableland0 = tableland0.dropna(subset=['ราคาทรัพย์']) #ข้อมูล Nan เยอะไป dropna ทำให้ข้อมูลหายหมด

# %%
tableland0.isnull().any() #Clean
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
tableland0.count() #40 data
# Out:
# post id       40
# ราคาทรัพย์    40
# ประเมิน1      40
# ประเมิน2      40
# dtype: int64

# %% [markdown]
# ##For loop

# %%
checkland1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว่้ใน list
checkland2 = list()
for row in tableland0.iterrows():
    checkland1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    checkland2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
checkland1
checkland2
# แต่ละ row ใน table จะทำใช้ function 'checkvalue' เพื่อหาค่าแล้วเพิ่มใน check1
# Out:
# [1.4,
#  1.2416666666666667,
#  1.2857142857142858,
#  1.0833333333333333,
#  1.2,
#  1.2,
#  1.2692307692307692,
#  1.1363636363636365,
#  1.2,
#  1.1166666666666667,
#  1.3333333333333333,
#  1.0909090909090908,
#  2.8125,
#  1.0,
#  1.0606060606060606,
#  1.9166666666666667,
#  1.1666666666666667,
#  1.2,
#  1.12,
#  1.225,
#  1.2375,
#  1.16,
#  1.01,
#  1.1583333333333334,
#  1.0833333333333333,
#  1.1583333333333334,
#  1.0968333333333333,
#  1.1363636363636365,
#  1.125,
#  1.0625,
#  1.18,
#  1.25,
#  1.0555555555555556,
#  1.2666666666666666,
#  5.294117647058823,
#  1.2075,
#  1.08481195462774,
#  1.1,
#  1.1363636363636365,
#  1.2075]

# %%
tableland0['Check1'] = checkland1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
tableland0['Check2'] = checkland2
tableland0
# Out:
# <ipython-input-55-c9b408b9d1aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableland0['Check1'] = checkland1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
# <ipython-input-55-c9b408b9d1aa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableland0['Check2'] = checkland2
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1    https://nayoo.co/khonkaen/posts/1033   2800000.0   1800000.0   2000000.0
# ...

# %%
tableland0= tableland0.sort_values(by=['Check1'],ascending=False) # Clean
tableland0
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 7    https://nayoo.co/khonkaen/posts/1726  90000000.0  18000000.0  70000000.0
# 19   https://nayoo.co/khonkaen/posts/2007  16500000.0   3500000.0  13000000.0
# 70   https://nayoo.co/khonkaen/posts/1639   3000000.0  12000000.0   3500000.0
# 104  https://nayoo.co/khonkaen/posts/1921   8080000.0   2800000.0   8000000.0
# 132  https://nayoo.co/khonkaen/posts/1638   4500000.0   2000000.0   4000000.0
# 4    https://nayoo.co/khonkaen/posts/1711  14900000.0   8000000.0  12000000.0
# 10   https://nayoo.co/khonkaen/posts/1732  65000000.0  35000000.0  60000000.0
# 102  https://nayoo.co/khonkaen/posts/1685   2900000.0   1600000.0   2500000.0
# 25   https://nayoo.co/khonkaen/posts/2045  12000000.0   7500000.0  10000000.0
# 142  https://nayoo.co/khonkaen/posts/3239   1900000.0   1200000.0   1500000.0
# 1    https://nayoo.co/khonkaen/posts/1033   2800000.0   1800000.0   2000000.0
# ...

# %%
tableland0 = tableland0.sort_values(by=['Check2'],ascending=False) #148 not clean 0 เกินมา 1 ตัว
tableland0
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 144  https://nayoo.co/khonkaen/posts/3341   1700000.0   1600000.0   9000000.0
# 35   https://nayoo.co/khonkaen/posts/3219   4500000.0   4000000.0   1600000.0
# 41   https://nayoo.co/khonkaen/posts/3601   2300000.0   1900000.0   1200000.0
# 1    https://nayoo.co/khonkaen/posts/1033   2800000.0   1800000.0   2000000.0
# 31   https://nayoo.co/khonkaen/posts/2194   2400000.0   2000000.0   1800000.0
# 7    https://nayoo.co/khonkaen/posts/1726  90000000.0  18000000.0  70000000.0
# 19   https://nayoo.co/khonkaen/posts/2007  16500000.0   3500000.0  13000000.0
# 142  https://nayoo.co/khonkaen/posts/3239   1900000.0   1200000.0   1500000.0
# 138  https://nayoo.co/khonkaen/posts/2510  15000000.0  12000000.0  12000000.0
# 4    https://nayoo.co/khonkaen/posts/1711  14900000.0   8000000.0  12000000.0
# 100  https://nayoo.co/khonkaen/posts/1663   1485000.0   1500000.0   1200000.0
# ...

# %%
tableland0.iloc[0, 3]
missing = tableland0.iloc[0, 3]
missing1 = missing/10 
missing1
# Out:
# 900000.0

# %%
tableland0.iloc[0, 3] = missing1

# %%
tableland0 #clean
# Out:
#                                   post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 144  https://nayoo.co/khonkaen/posts/3341   1700000.0   1600000.0    900000.0
# 35   https://nayoo.co/khonkaen/posts/3219   4500000.0   4000000.0   1600000.0
# 41   https://nayoo.co/khonkaen/posts/3601   2300000.0   1900000.0   1200000.0
# 1    https://nayoo.co/khonkaen/posts/1033   2800000.0   1800000.0   2000000.0
# 31   https://nayoo.co/khonkaen/posts/2194   2400000.0   2000000.0   1800000.0
# 7    https://nayoo.co/khonkaen/posts/1726  90000000.0  18000000.0  70000000.0
# 19   https://nayoo.co/khonkaen/posts/2007  16500000.0   3500000.0  13000000.0
# 142  https://nayoo.co/khonkaen/posts/3239   1900000.0   1200000.0   1500000.0
# 138  https://nayoo.co/khonkaen/posts/2510  15000000.0  12000000.0  12000000.0
# 4    https://nayoo.co/khonkaen/posts/1711  14900000.0   8000000.0  12000000.0
# 100  https://nayoo.co/khonkaen/posts/1663   1485000.0   1500000.0   1200000.0
# ...

# %% [markdown]
# ###def function mape
# - ค่าเกิน 9,10 ก็ลบ ศูนย์ ถ้าเกิน 2 คนประเมินว่าแบบนั้นเลย

# %%
#ใช้คอลัมน์ ประเมิน 1 ,ประเมิน 2 ในการคำนวณ
#คอลัมน์ Check1,2 ไว้เช็คว่าค่าพุ่งเกินไหม
tableland1= tableland0['ประเมิน1']
tableland2= tableland0['ประเมิน2']
tableland3= tableland0['ราคาทรัพย์']

# %%
mapetable = mape(tableland3, tableland1)
mapetable # ค่า mape ของผู้ประเมิน1 กับผู้ประเมิน 2
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetable)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.32477881661863095

# %%
mapetable2 = mape(tableland3, tableland2)
mapetable2 # ค่า mape ของผู้ประเมิน1 กับ ราคาทรัพย์
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetable2)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.16690769318722384

# %%
mapetable3 = mape(tableland2, tableland3)
mapetable3
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetable3)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.24011957176504053

# %% [markdown]
# #ทาวน์โฮม

# %%
townh = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม',skiprows=0) #เลือก ชีท ที่ดิน
townh
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
townh.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# count     240.000000  1.220000e+02         2.400000e+02
# mean        1.500000  2.011066e+06         1.827917e+06
# std         0.501045  9.274469e+05         7.870919e+05
# min         1.000000  6.050000e+05         3.500000e+05
# 25%         1.000000  1.287000e+06         1.300000e+06
# 50%         1.500000  1.750000e+06         1.650000e+06
# 75%         2.000000  2.590000e+06         2.350000e+06
# max         2.000000  4.730000e+06         4.200000e+06
#
#        เหตุผลไม่มั่นใจราคาประเมิน  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# count                         0.0         0.0          0.0          0.0
# mean                          NaN         NaN          NaN          NaN
# std                           NaN         NaN          NaN          NaN
# min                           NaN         NaN          NaN          NaN
# 25%                           NaN         NaN          NaN          NaN
# ...

# %%
townh[townh['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count() #มั่นใจทุกคน
# Out:
# ID ผู้ประเมิน                     240
# post id                           240
# property_type                     240
# ความมั่นใจในการเมินราคาทรัพย์     240
# ราคาทรัพย์                        122
# ประเมินราคาซื้อ-ขาย               240
# ปัจจัยในการประเมินราคาซื้อ-ขาย    240
# เหตุผลไม่มั่นใจราคาประเมิน          0
# ให้คะแนนทรัพย์                    240
# Unnamed: 9                          0
# Unnamed: 10                         0
# Unnamed: 11                         0
# Unnamed: 12                         1
# dtype: int64

# %%
townh['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    120
# 2    120
# Name: ID ผู้ประเมิน, dtype: int64

# %%
townh1 = townh[townh['ID ผู้ประเมิน']==1]
townh1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 6                1    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 8                1    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 125              1  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 126              1  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 127              1  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 128              1  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 129              1  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
townh2 = townh[townh['ID ผู้ประเมิน']==2]
townh2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# ##Map Data

# %%
townh2['ประเมิน1'] = townh2['post id'].map(townh1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
townh2
# Out:
# <ipython-input-71-891188a31380>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townh2['ประเมิน1'] = townh2['post id'].map(townh1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# ...

# %%
townh2 = townh2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
townh2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์   ประเมิน2  \
# ...

# %%
tabletown = townh2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
tabletown
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547         NaN  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551         NaN  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434         NaN  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501         NaN  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367         NaN  1700000.0  1700000.0
#
# [120 rows x 4 columns]

# %% [markdown]
# ##Check Data

# %%
tabletown.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์     True
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
tabletown = tabletown.dropna(subset=['ราคาทรัพย์']) #row หายไป 59 row หลัง dropna
tabletown
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3     https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5     https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7     https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9     https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                    ...         ...        ...        ...
# 176  https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 177  https://nayoo.co/khonkaen/posts/3599   1700000.0  1800000.0  1700000.0
# 178  https://nayoo.co/khonkaen/posts/3661   1900000.0  2000000.0  1900000.0
# 179  https://nayoo.co/khonkaen/posts/3719   1550000.0  1400000.0  1500000.0
# 196   https://nayoo.co/khonkaen/posts/616   1540000.0  1500000.0  1500000.0
#
# [61 rows x 4 columns]

# %% [markdown]
# ##For loop

# %%
checktown1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว่้ใน list
checktown2 = list()
for row in tabletown.iterrows():
    checktown1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    checktown2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
checktown1
checktown2
# แต่ละ row ใน table จะทำใช้ function 'checkvalue' เพื่อหาค่าแล้วเพิ่มใน check1
# Out:
# [1.4354066985645932,
#  1.6042780748663101,
#  1.1363636363636365,
#  1.203125,
#  1.2375,
#  1.134375,
#  1.1,
#  1.144,
#  1.1825,
#  1.0620689655172413,
#  1.1,
#  1.144,
#  1.43,
#  1.0371428571428571,
#  1.1,
#  1.375,
#  1.0266666666666666,
#  1.05,
#  1.0725,
#  1.4450867052023122,
#  1.1,
#  1.0743801652892562,
#  1.1916666666666667,
#  1.03125,
#  1.12,
#  1.0294117647058822,
#  1.0666666666666667,
#  1.0119047619047619,
#  1.1083333333333334,
#  1.037037037037037,
#  1.0043668122270741,
#  1.0,
#  1.0,
#  1.04,
#  1.036,
#  1.0833333333333333,
#  1.0112359550561798,
#  1.0,
#  1.004566210045662,
#  1.0692307692307692,
#  1.0784313725490196,
#  1.0714285714285714,
#  1.00625,
#  1.0357142857142858,
#  1.0,
#  1.0357142857142858,
#  1.0416666666666667,
#  1.0826086956521739,
#  1.0692307692307692,
#  1.0391304347826087,
#  1.0217391304347827,
#  1.0294117647058822,
#  1.0,
#  1.1214953271028036,
#  1.004566210045662,
#  1.0,
#  5.475,
#  1.0,
#  1.0,
#  1.0333333333333334,
# ...

# %%
tabletown['Check1'] = checktown1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
tabletown['Check2'] = checktown2
tabletown
# Out:
# <ipython-input-77-171c23031061>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabletown['Check1'] = checktown1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
# <ipython-input-77-171c23031061>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabletown['Check2'] = checktown2
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 1     https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# ...

# %%
tabletown= tabletown.sort_values(by=['Check1'],ascending=False) # Clean
tabletown
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176  https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 132   https://nayoo.co/khonkaen/posts/619   1430000.0   950000.0  1000000.0
# 1     https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 174  https://nayoo.co/khonkaen/posts/3478   2190000.0  1500000.0  2200000.0
# 135   https://nayoo.co/khonkaen/posts/652   1100000.0   800000.0   800000.0
# ..                                    ...         ...        ...        ...
# 9     https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# 133   https://nayoo.co/khonkaen/posts/642   3630000.0  3600000.0  3500000.0
# 162  https://nayoo.co/khonkaen/posts/2242   1610000.0  1600000.0  1600000.0
# 5     https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 167  https://nayoo.co/khonkaen/posts/2829   2490000.0  2500000.0  2300000.0
#
#        Check1    Check2
# 176  6.257143  5.475000
# ...

# %%
tabletown= tabletown.sort_values(by=['Check2'],ascending=False) # Clean
tabletown
# Out:
#                                   post id  ราคาทรัพย์   ประเมิน1   ประเมิน2  \
# 176  https://nayoo.co/khonkaen/posts/3528   2190000.0   350000.0   400000.0
# 3     https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 139   https://nayoo.co/khonkaen/posts/705   1038000.0  1200000.0  1500000.0
# 1     https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 132   https://nayoo.co/khonkaen/posts/619   1430000.0   950000.0  1000000.0
# ..                                    ...         ...        ...        ...
# 164  https://nayoo.co/khonkaen/posts/2248   1200000.0  1500000.0  1200000.0
# 157  https://nayoo.co/khonkaen/posts/2185   2600000.0  2500000.0  2600000.0
# 152  https://nayoo.co/khonkaen/posts/2011   1100000.0   900000.0  1100000.0
# 177  https://nayoo.co/khonkaen/posts/3599   1700000.0  1800000.0  1700000.0
# 172  https://nayoo.co/khonkaen/posts/3394   1200000.0  1300000.0  1200000.0
#
#        Check1    Check2
# 176  6.257143  5.475000
# ...

# %% [markdown]
# ###def function mape

# %%
tabletown1 = tabletown['ประเมิน1']
tabletown2 = tabletown['ประเมิน2']
tabletown3 = tabletown['ราคาทรัพย์']

# %%
mapetown1 = mape(tabletown1, tabletown2)
mapetown1 
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapetown1)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.12553213977323965

# %%
mapetown2 = mape(tabletown1, tabletown3)
mapetown2 
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetown2)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.20119357796868997

# %%
mapetown3 = mape(tabletown2, tabletown3)
mapetown3 
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapetown3)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.15838059290617415

# %% [markdown]
# #อาคารพาณิชย์

# %%
build= pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์',skiprows=0) #เลือก ชีท อาคารพาณิชย์
build
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
build.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# count      20.000000  2.000000e+01         2.000000e+01
# mean        1.500000  7.710000e+06         6.935000e+06
# std         0.512989  5.768052e+06         4.646818e+06
# min         1.000000  2.400000e+06         2.100000e+06
# 25%         1.000000  3.900000e+06         3.750000e+06
# 50%         1.500000  6.000000e+06         5.500000e+06
# 75%         2.000000  9.000000e+06         8.500000e+06
# max         2.000000  2.250000e+07         2.000000e+07
#
#        เหตุผลไม่มั่นใจราคาประเมิน  Unnamed: 9  Unnamed: 11  Unnamed: 12  \
# count                         0.0   20.000000          0.0          0.0
# mean                          NaN    2.750000          NaN          NaN
# std                           NaN    0.850696          NaN          NaN
# min                           NaN    2.000000          NaN          NaN
# 25%                           NaN    2.000000          NaN          NaN
# ...

# %%
build[build['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count() #มั่นใจทุกคน 20 คน
# Out:
# ID ผู้ประเมิน                     20
# post id                           20
# property_type                     20
# ความมั่นใจในการเมินราคาทรัพย์     20
# ราคาทรัพย์                        20
# ประเมินราคาซื้อ-ขาย               20
# ปัจจัยในการประเมินราคาซื้อ-ขาย    20
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    20
# Unnamed: 9                        20
# Unnamed: 10                       20
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        1
# dtype: int64

# %%
build1 = build[build['ID ผู้ประเมิน']==1]
build1
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 12              1   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 14              1  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 16              1  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 18              1  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
build2 = build[build['ID ผู้ประเมิน']==2]
build2
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 15              2  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 17              2  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 19              2  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# ##Map Data

# %%
build2['ประเมิน1'] = build2['post id'].map(build1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
build2
# Out:
# <ipython-input-89-7b4bae19d817>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   build2['ประเมิน1'] = build2['post id'].map(build1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
tablebuild = build2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tablebuild
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 15              2  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 17              2  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 19              2  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์    ประเมิน2  \
# ...

# %%
tablebuild0 = tablebuild[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
tablebuild0
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0

# %% [markdown]
# ##Check Data

# %%
tablebuild0.isnull().any() #Clean
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %% [markdown]
# ##For loop

# %%
checkbuild1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว่้ใน list
checkbuild2 = list()
for row in tablebuild0.iterrows():
    checkbuild1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    checkbuild2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
checkbuild1 
checkbuild2
# แต่ละ row ใน table จะทำใช้ function 'checkvalue' เพื่อหาค่าแล้วเพิ่มใน check1
# Out:
# [1.1428571428571428,
#  1.0,
#  1.125,
#  1.1428571428571428,
#  1.3,
#  1.2,
#  1.1428571428571428,
#  1.0,
#  1.1428571428571428,
#  1.1111111111111112]

# %%
tablebuild0['Check1'] = checkbuild1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
tablebuild0['Check2'] = checkbuild2
tablebuild0
# Out:
# <ipython-input-94-78258b8e5f3a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tablebuild0['Check1'] = checkbuild1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
# <ipython-input-94-78258b8e5f3a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tablebuild0['Check2'] = checkbuild2
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# ...

# %%
tablebuild0= tablebuild0.sort_values(by=['Check1'],ascending=False) # Clean
tablebuild0
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
#
#       Check1    Check2
# 9   1.772727  1.300000
# 5   1.666667  1.125000
# 11  1.333333  1.200000
# 15  1.315789  1.000000
# ...

# %%
tablebuild0= tablebuild0.sort_values(by=['Check2'],ascending=False) # Clean
tablebuild0
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
#
#       Check1    Check2
# 9   1.772727  1.300000
# 11  1.333333  1.200000
# 1   1.166667  1.142857
# 7   1.142857  1.142857
# ...

# %% [markdown]
# ###def function mape

# %%
tablebuild1 = tablebuild0['ประเมิน1']
tablebuild2 = tablebuild0['ประเมิน2']
tablebuild3 = tablebuild0['ราคาทรัพย์']

# %%
mapebuild1 = mape(tablebuild1, tablebuild2)
mapebuild1 
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่', mapebuild1)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ผู้ประเมิน 2 มีค่า MAPE อยู่ที่ 0.2158208906103643

# %%
mapebuild2 = mape(tablebuild1, tablebuild3)
mapebuild2 
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapebuild2)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 1 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.254518341307815

# %%
mapebuild3 = mape(tablebuild2, tablebuild3)
mapebuild3
print(f'ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่', mapebuild3)
# Out:
# ความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของผู้ประเมินคนที่ 2 กับ ราคาทรัพย์ มีค่า MAPE อยู่ที่ 0.12428571428571429

# %% [markdown]
# ##HW3 visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %% [markdown]
# ##Load ตารางจาก google sheet

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
gsht = gc.open_by_key('1zNhL_S76z2RUxfkm6yj6OCiasPkzxq75bk_ScB3JxCE')

# %%
worksheet = gsht.worksheet("บ้าน")

# %%
rows = worksheet.get_all_values()
home = pd.DataFrame.from_records(rows)

# %%
home
# Out:
#                   0                                     1              2  \
# 0     ID ผู้ประเมิน                               post id  property_type
# 1                01    https://nayoo.co/khonkaen/posts/25     บ้านเดี่ยว
# 2                02    https://nayoo.co/khonkaen/posts/25     บ้านเดี่ยว
# 3                01    https://nayoo.co/khonkaen/posts/33     บ้านเดี่ยว
# 4                02    https://nayoo.co/khonkaen/posts/33     บ้านเดี่ยว
# ...             ...                                   ...            ...
# 1216             01  https://nayoo.co/khonkaen/posts/6257     บ้านเดี่ยว
# 1217             02  https://nayoo.co/khonkaen/posts/6258     บ้านเดี่ยว
# 1218             01  https://nayoo.co/khonkaen/posts/6258     บ้านเดี่ยว
# 1219             02  https://nayoo.co/khonkaen/posts/6260     บ้านเดี่ยว
# 1220             01  https://nayoo.co/khonkaen/posts/6260     บ้านเดี่ยว
#
#                                   3           4                    5  \
# ...

# %%
home.columns = home.iloc[0]
home.head()
# Out:
# 0  ID ผู้ประเมิน                             post id  property_type  \
# 0  ID ผู้ประเมิน                             post id  property_type
# 1             01  https://nayoo.co/khonkaen/posts/25     บ้านเดี่ยว
# 2             02  https://nayoo.co/khonkaen/posts/25     บ้านเดี่ยว
# 3             01  https://nayoo.co/khonkaen/posts/33     บ้านเดี่ยว
# 4             02  https://nayoo.co/khonkaen/posts/33     บ้านเดี่ยว
#
# 0  ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0  ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# 1                         มั่นใจ     2890000              2500000
# 2                         มั่นใจ     2890000              2700000
# 3                         มั่นใจ     2600000              2200000
# 4                         มั่นใจ     2600000              2400000
#
# 0                     ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                     ปัจจัยในการประเมินราคาซื้อ-ขาย
# ...

# %%
home = home.iloc[1:].reset_index().iloc[:,1:] #ตัดคอลัมเกิน

# %%
home.head()
# Out:
# 0 ID ผู้ประเมิน                              post id property_type  \
# 0            01   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1            02   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2            01   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3            02   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4            01  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
# 0 ความมั่นใจในการเมินราคาทรัพย์ ราคาทรัพย์ ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ    2890000             2500000
# 1                        มั่นใจ    2890000             2700000
# 2                        มั่นใจ    2600000             2200000
# 3                        มั่นใจ    2600000             2400000
# 4                        มั่นใจ    6050000             5000000
#
# 0                     ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %%
from sklearn.metrics import mean_absolute_percentage_error as MAPE #อีกวิธี
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
link = 'https://docs.google.com/spreadsheets/d/1zNhL_S76z2RUxfkm6yj6OCiasPkzxq75bk_ScB3JxCE/export?format=xlsx'
Home = pd.read_excel(link, sheet_name='บ้าน')

# %%
id1 = Home[Home['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = Home[Home['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])

# %%
id2['ประเมิน1'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
id2 = id2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tableHome = id2[['post id','ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์']]
tableHome
# Out:
#                                    post id ความมั่นใจในการเมินราคาทรัพย์  \
# 1       https://nayoo.co/khonkaen/posts/25                        มั่นใจ
# 3       https://nayoo.co/khonkaen/posts/33                        มั่นใจ
# 5      https://nayoo.co/khonkaen/posts/495                        มั่นใจ
# 7      https://nayoo.co/khonkaen/posts/564                        มั่นใจ
# 9      https://nayoo.co/khonkaen/posts/566                        มั่นใจ
# ...                                    ...                           ...
# 1210  https://nayoo.co/khonkaen/posts/6255                        มั่นใจ
# 1212  https://nayoo.co/khonkaen/posts/6256                        มั่นใจ
# 1214  https://nayoo.co/khonkaen/posts/6257                        มั่นใจ
# 1216  https://nayoo.co/khonkaen/posts/6258                        มั่นใจ
# 1218  https://nayoo.co/khonkaen/posts/6260                        มั่นใจ
#
#       ราคาทรัพย์   ประเมิน1   ประเมิน2                     ให้คะแนนทรัพย์
# ...

# %%
def checkvalue(a, b):
  return max(a/b, b/a)

# %%
check1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว้ใน list
check2 = list()
for row in tableHome.iterrows():
    check1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    check2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
check1
check2
# Out:
# [1.0703703703703704,
#  1.0833333333333333,
#  1.487603305785124,
#  1.1891891891891893,
#  1.1,
#  1.0314685314685315,
#  1.050420168067227,
#  1.0416666666666667,
#  1.1403333333333334,
#  1.0175,
#  1.0476190476190477,
#  1.03125,
#  1.0214285714285714,
#  1.0607142857142857,
#  1.025,
#  1.0607142857142857,
#  1.0847222222222221,
#  1.0371428571428571,
#  1.0,
#  1.125,
#  1.1049723756906078,
#  1.1904761904761905,
#  1.0888888888888888,
#  1.0054461667364893,
#  1.0425531914893618,
#  1.125,
#  1.0434782608695652,
#  1.0364145658263306,
#  1.0,
#  1.0324483775811208,
#  1.04,
#  1.2,
#  1.04,
#  1.1318181818181818,
#  1.0,
#  1.045,
#  1.0526315789473684,
#  3.3333333333333335,
#  1.0227272727272727,
#  1.04,
#  1.08,
#  1.2903225806451613,
#  1.1219512195121952,
#  1.125,
#  1.075268817204301,
#  1.2322941176470588,
#  1.0755555555555556,
#  1.0775862068965518,
#  1.169004676018704,
#  1.0158013544018059,
#  1.048951048951049,
#  1.1777777777777778,
#  1.045,
# ...

# %%
tableHome['Check1'] = check1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
tableHome['Check2'] = check2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
tableHome.sort_values(by=['Check2'],ascending=False)
# Out:
# <ipython-input-108-14971fd11754>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableHome['Check1'] = check1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
# <ipython-input-108-14971fd11754>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableHome['Check2'] = check2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
#                                     post id ความมั่นใจในการเมินราคาทรัพย์  \
# 802    https://nayoo.co/khonkaen/posts/3208                        มั่นใจ
# ...

# %%
missing1 = tableHome.iloc[131,4]/10
missing2 = tableHome.iloc[234,4]/10
tableHome.iloc[131,4] = missing1
tableHome.iloc[234,4] = missing2
tableHome.sort_values(by=['Check2'],ascending=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                                     post id ความมั่นใจในการเมินราคาทรัพย์  \
# 802    https://nayoo.co/khonkaen/posts/3208                        มั่นใจ
# 544    https://nayoo.co/khonkaen/posts/1619                        มั่นใจ
# 292     https://nayoo.co/khonkaen/posts/622                        มั่นใจ
# 75        https://nayoo.co/khonkaen/posts/1                        มั่นใจ
# 1070   https://nayoo.co/khonkaen/posts/6037                        มั่นใจ
# ...                                     ...                           ...
# ...

# %%
id1MAPE = MAPE(tableHome['ประเมิน1'],pd.to_numeric(tableHome['ราคาทรัพย์']))
id2MAPE = MAPE(tableHome['ประเมิน2'],pd.to_numeric(tableHome['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
one2two = MAPE(tableHome['ประเมิน1'],tableHome['ประเมิน2'])
two2one = MAPE(tableHome['ประเมิน2'],tableHome['ประเมิน1'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(tableHome)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 12.99%
# นักประเมิน คนที่ 2 = 10.78%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.43%
# จำนวนทรัพย์ทั้งหมด 498 ทรัพย์

# %% [markdown]
# ##Plot Graph

# %%
# !pip install squarify
import matplotlib.pyplot as plt
import squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
tableHome.columns
# Out:
# Index(['post id', 'ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมิน1',
#        'ประเมิน2', 'ให้คะแนนทรัพย์', 'Check1', 'Check2'],
#       dtype='object')

# %%
homecorr = tableHome[['ราคาทรัพย์', 'ประเมิน1','ประเมิน2','ความมั่นใจในการเมินราคาทรัพย์','ให้คะแนนทรัพย์']]
homecorr.corr(method='pearson')
# Out:
#             ราคาทรัพย์  ประเมิน1  ประเมิน2
# ราคาทรัพย์    1.000000   0.92096  0.920139
# ประเมิน1      0.920960   1.00000  0.980610
# ประเมิน2      0.920139   0.98061  1.000000

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
corr = homecorr.corr()
sm.graphics.plot_corr(corr, xnames=list(corr.columns), cmap='bone')
plt.show()

# %%
sns.pairplot(homecorr, hue="ความมั่นใจในการเมินราคาทรัพย์")

# %%
sns.pairplot(homecorr, hue="ให้คะแนนทรัพย์", diag_kind="hist")

# %% [markdown]
# ##ที่ดิน

# %%
link = 'https://docs.google.com/spreadsheets/d/1zNhL_S76z2RUxfkm6yj6OCiasPkzxq75bk_ScB3JxCE/export?format=xlsx'
land = pd.read_excel(link, sheet_name='ที่ดิน')

# %%
idl1 = land[land['ID ผู้ประเมิน']==1]
idl1 = idl1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl2 = land[land['ID ผู้ประเมิน']==2]
idl2 = idl2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])

# %%
idl2['ประเมิน1'] = idl2['post id'].map(idl1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
idl2 = idl2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tableLand = idl2[['post id','ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์']]
tableLand
# Out:
#                                    post id ความมั่นใจในการเมินราคาทรัพย์  \
# 1     https://nayoo.co/khonkaen/posts/1033                        มั่นใจ
# 4     https://nayoo.co/khonkaen/posts/1711                        มั่นใจ
# 7     https://nayoo.co/khonkaen/posts/1726                        มั่นใจ
# 10    https://nayoo.co/khonkaen/posts/1732                        มั่นใจ
# 13    https://nayoo.co/khonkaen/posts/1866                        มั่นใจ
# ..                                     ...                           ...
# 200  https://nayoo.co/khonkaen/posts/14539                        มั่นใจ
# 202  https://nayoo.co/khonkaen/posts/16072                        มั่นใจ
# 204  https://nayoo.co/khonkaen/posts/17093                        มั่นใจ
# 206  https://nayoo.co/khonkaen/posts/17112                        มั่นใจ
# 208  https://nayoo.co/khonkaen/posts/17145                        มั่นใจ
#
#      ราคาทรัพย์    ประเมิน1    ประเมิน2                      ให้คะแนนทรัพย์
# ...

# %%
def checkvalue(a, b):
  return max(a/b, b/a)

# %%
checkland1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว้ใน list
checkland2 = list()
for row in tableLand.iterrows():
    checkland1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    checkland2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
checkland1
checkland2
# Out:
# [1.4,
#  1.2416666666666667,
#  1.2857142857142858,
#  1.0833333333333333,
#  1.2,
#  1.2,
#  1.2692307692307692,
#  1.1363636363636365,
#  1.2,
#  1.1166666666666667,
#  1.3333333333333333,
#  1.0909090909090908,
#  2.8125,
#  1.0,
#  1.0606060606060606,
#  1.9166666666666667,
#  1.0416666666666667,
#  1.0285714285714285,
#  13.61111111111111,
#  1.9285714285714286,
#  1.1111111111111112,
#  1.1,
#  1.1764705882352942,
#  1.25,
#  10.909090909090908,
#  1.0012515644555695,
#  1.1111111111111112,
#  1.35,
#  1.2753333333333334,
#  1.25,
#  1.1666666666666667,
#  1.2,
#  1.1904761904761905,
#  1.12,
#  1.225,
#  1.2666666666666666,
#  1.2,
#  1.2,
#  1.1363636363636365,
#  1.144,
#  1.2,
#  1.1627906976744187,
#  1.0666666666666667,
#  1.0588235294117647,
#  1.2352941176470589,
#  1.2375,
#  1.16,
#  1.01,
#  1.1583333333333334,
#  1.0833333333333333,
#  1.1583333333333334,
#  1.3,
#  1.0476190476190477,
#  1.0714285714285714,
#  1.075,
#  1.333,
#  1.0769230769230769,
#  1.25,
# ...

# %%
tableLand['Check1'] = checkland1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
tableLand[  'Check2'] = checkland2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
tableLand.sort_values(by=['Check2'],ascending=False)
# Out:
# <ipython-input-122-2b1367fbae22>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableLand['Check1'] = checkland1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
# <ipython-input-122-2b1367fbae22>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableLand[  'Check2'] = checkland2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
#                                    post id ความมั่นใจในการเมินราคาทรัพย์  \
# 47    https://nayoo.co/khonkaen/posts/7349                        มั่นใจ
# ...

# %%
missingL1 = tableLand.iloc[18,3]*10
missingL2 = tableLand.iloc[18,4]*10
missingL3 = tableLand.iloc[24,3]*10
missingL4 = tableLand.iloc[24,4]*10
missingL5 = tableLand.iloc[69,4]/10
missingL6 = tableLand.iloc[89,4]/10
tableLand.iloc[18,3] = missingL1
tableLand.iloc[18,4] = missingL2
tableLand.iloc[24,3] = missingL3
tableLand.iloc[24,4] = missingL4
tableLand.iloc[69,4] = missingL5
tableLand.iloc[89,4] = missingL6
tableLand.sort_values(by=['Check2'],ascending=False)
#index 47 ราคาทรัพย์ 245 ล้าน ->  ประเมิน1 = 24 ล้าน ประเมิน2 = 18ล้าน -> ขาด 0 แก้เป็น *10 ทั้ง 2 column [19]
#index 58 ราคาทรัพย์ 120 ล้าน ->  ประเมิน1 = 14 ล้าน ประเมิน2 = 11ล้าน -> ขาด 0 แก้เป็น *10 ทั้ง 2 column [25]
#index 148 ราคาทรัพย์ 7.3ล้าน -> ประเมิน2 = 80 ล้าน -> เกิน 0 /10  [20]
#index 188 ราคาทรัพย์ 2.3ล้าน -> ประเมิน2 = 24 ล้าน -> เกิน 0/10  [89]
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                                    post id ความมั่นใจในการเมินราคาทรัพย์  \
# 47    https://nayoo.co/khonkaen/posts/7349                        มั่นใจ
# 58    https://nayoo.co/khonkaen/posts/9203                        มั่นใจ
# 148   https://nayoo.co/khonkaen/posts/3561                        มั่นใจ
# 188  https://nayoo.co/khonkaen/posts/12250                        มั่นใจ
# 144   https://nayoo.co/khonkaen/posts/3341                        มั่นใจ
# ..                                     ...                           ...
# ...

# %%
idl1MAPE = MAPE(tableLand['ประเมิน1'],pd.to_numeric(tableLand['ราคาทรัพย์']))
idl2MAPE = MAPE(tableLand['ประเมิน2'],pd.to_numeric(tableLand['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {idl1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idl2MAPE*100:.2f}%')
onel2two = MAPE(tableLand['ประเมิน1'],tableLand['ประเมิน2'])
twol2one = MAPE(tableLand['ประเมิน2'],tableLand['ประเมิน1'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((onel2two)+(twol2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(tableLand)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 63.12%
# นักประเมิน คนที่ 2 = 19.94%
# ความผิดพลาดระหว่างนักประเมินทั้ง 47.37%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %% [markdown]
# ##Graph

# %%
landcorr = tableLand[['ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมิน1','ประเมิน2', 'ให้คะแนนทรัพย์']]

# %%
landcorr.corr(method='pearson')
# Out:
#             ราคาทรัพย์  ประเมิน1  ประเมิน2
# ราคาทรัพย์    1.000000  0.945128  0.995371
# ประเมิน1      0.945128  1.000000  0.936201
# ประเมิน2      0.995371  0.936201  1.000000

# %%
landcorr1 = landcorr.corr()

# %%
sm.graphics.plot_corr(landcorr1, xnames=list(corr.columns), cmap='Reds')
plt.show()

# %%
sns.pairplot(landcorr, hue="ความมั่นใจในการเมินราคาทรัพย์")

# %%
sns.pairplot(landcorr, hue="ให้คะแนนทรัพย์", diag_kind="hist")

# %% [markdown]
# ##ทาวน์โฮม

# %%
link = 'https://docs.google.com/spreadsheets/d/1zNhL_S76z2RUxfkm6yj6OCiasPkzxq75bk_ScB3JxCE/export?format=xlsx'
Townhome = pd.read_excel(link, sheet_name='ทาวน์โฮม')

# %%
idt1 = Townhome[Townhome['ID ผู้ประเมิน']==1]
idt1 = idt1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idt2 = Townhome[Townhome['ID ผู้ประเมิน']==2]
idt2 = idt2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])

# %%
idt2['ประเมิน1'] = idt2['post id'].map(idt1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
idt2 = idt2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tableTownhome = idt2[['post id','ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์']]
tableTownhome
# Out:
#                                    post id ความมั่นใจในการเมินราคาทรัพย์  \
# 1      https://nayoo.co/khonkaen/posts/548                        มั่นใจ
# 3      https://nayoo.co/khonkaen/posts/549                        มั่นใจ
# 5      https://nayoo.co/khonkaen/posts/579                        มั่นใจ
# 7      https://nayoo.co/khonkaen/posts/580                        มั่นใจ
# 9      https://nayoo.co/khonkaen/posts/582                        มั่นใจ
# ..                                     ...                           ...
# 235  https://nayoo.co/khonkaen/posts/18547                        มั่นใจ
# 236  https://nayoo.co/khonkaen/posts/18551                        มั่นใจ
# 237  https://nayoo.co/khonkaen/posts/19434                        มั่นใจ
# 238  https://nayoo.co/khonkaen/posts/19501                        มั่นใจ
# 239  https://nayoo.co/khonkaen/posts/20367                        มั่นใจ
#
#      ราคาทรัพย์   ประเมิน1   ประเมิน2                     ให้คะแนนทรัพย์
# ...

# %%
checkth1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว่้ใน list
checkth2 = list()
for row in tableTownhome.iterrows():
    checkth1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    checkth2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
checkth1
checkth2
# Out:
# [1.4354066985645932,
#  1.6042780748663101,
#  1.5873015873015872,
#  1.203125,
#  1.4705882352941178,
#  1.065625,
#  1.1,
#  1.2820512820512822,
#  1.1825,
#  1.0620689655172413,
#  1.1,
#  1.144,
#  1.0256410256410255,
#  1.0371428571428571,
#  1.1,
#  1.0666666666666667,
#  1.0266666666666666,
#  1.05,
#  1.0909090909090908,
#  1.4450867052023122,
#  1.1,
#  1.0743801652892562,
#  1.1916666666666667,
#  1.03125,
#  1.12,
#  1.0294117647058822,
#  1.0666666666666667,
#  1.069182389937107,
#  1.1083333333333334,
#  1.037037037037037,
#  1.0043668122270741,
#  1.0,
#  1.0,
#  1.04,
#  1.036,
#  1.0833333333333333,
#  1.0112359550561798,
#  1.0,
#  1.004566210045662,
#  1.0692307692307692,
#  1.0784313725490196,
#  1.0714285714285714,
#  1.00625,
#  1.288888888888889,
#  1.0,
#  1.2083333333333333,
#  1.0416666666666667,
#  1.0826086956521739,
#  1.0692307692307692,
#  1.0391304347826087,
#  1.0217391304347827,
#  1.0294117647058822,
#  1.0,
#  1.1214953271028036,
# ...

# %%
tableTownhome['Check1'] = checkth1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
tableTownhome['Check2'] = checkth2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
tableTownhome.sort_values(by=['Check2'],ascending=False) #Clean
# Out:
# <ipython-input-135-09161526a834>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableTownhome['Check1'] = checkth1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
# <ipython-input-135-09161526a834>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableTownhome['Check2'] = checkth2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
#                                    post id ความมั่นใจในการเมินราคาทรัพย์  \
# 176   https://nayoo.co/khonkaen/posts/3528                        มั่นใจ
# ...

# %%
idt1MAPE = MAPE(tableTownhome['ประเมิน1'],pd.to_numeric(tableTownhome['ราคาทรัพย์']))
idt2MAPE = MAPE(tableTownhome['ประเมิน2'],pd.to_numeric(tableTownhome['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nTownhome\nนักประเมิน คนที่ 1 = {idt1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idt2MAPE*100:.2f}%')
onet2two = MAPE(tableTownhome['ประเมิน1'],tableTownhome['ประเมิน2'])
twot2one = MAPE(tableTownhome['ประเมิน2'],tableTownhome['ประเมิน1'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((onet2two)+(twot2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(tableTownhome)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# Townhome
# นักประเมิน คนที่ 1 = 15.26%
# นักประเมิน คนที่ 2 = 12.20%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %% [markdown]
# ##Graph

# %%
datath = tableTownhome[['ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมิน1','ประเมิน2', 'ให้คะแนนทรัพย์']]
datath.corr(method='pearson')
# Out:
#             ราคาทรัพย์  ประเมิน1  ประเมิน2
# ราคาทรัพย์    1.000000  0.930627  0.920421
# ประเมิน1      0.930627  1.000000  0.947670
# ประเมิน2      0.920421  0.947670  1.000000

# %%
thcorr = datath.corr()
sm.graphics.plot_corr(thcorr, xnames=list(corr.columns), cmap='Greens_r')
plt.show()

# %%
sns.pairplot(datath, hue="ความมั่นใจในการเมินราคาทรัพย์")

# %%
sns.pairplot(datath, hue="ให้คะแนนทรัพย์" ,diag_kind="hist")

# %% [markdown]
# ##อาคารพาณิชย์

# %%
link = 'https://docs.google.com/spreadsheets/d/1zNhL_S76z2RUxfkm6yj6OCiasPkzxq75bk_ScB3JxCE/export?format=xlsx'
build = pd.read_excel(link, sheet_name='อาคารพาณิชย์')

# %%
idb1 = build[build['ID ผู้ประเมิน']==1]
idb1 = idb1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idb2 = build[build['ID ผู้ประเมิน']==2]
idb2 = idb2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])

# %%
idb2['ประเมิน1'] = idb2['post id'].map(idb1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
idb2 = idb2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
tablebuild = idb2[['post id','ความมั่นใจในการเมินราคาทรัพย์','ราคาทรัพย์','ประเมิน1','ประเมิน2','ให้คะแนนทรัพย์']]
tablebuild
# Out:
#                                   post id ความมั่นใจในการเมินราคาทรัพย์  \
# 1       https://nayoo.co/khonkaen/posts/6                        มั่นใจ
# 3      https://nayoo.co/khonkaen/posts/17                        มั่นใจ
# 5      https://nayoo.co/khonkaen/posts/21                        มั่นใจ
# 7      https://nayoo.co/khonkaen/posts/22                        มั่นใจ
# 9      https://nayoo.co/khonkaen/posts/24                        มั่นใจ
# ..                                    ...                           ...
# 183  https://nayoo.co/khonkaen/posts/6168                        มั่นใจ
# 185  https://nayoo.co/khonkaen/posts/6169                        มั่นใจ
# 187  https://nayoo.co/khonkaen/posts/6176                        มั่นใจ
# 191  https://nayoo.co/khonkaen/posts/7137                        มั่นใจ
# 199  https://nayoo.co/khonkaen/posts/7705                        มั่นใจ
#
#      ราคาทรัพย์    ประเมิน1    ประเมิน2                      ให้คะแนนทรัพย์
# ...

# %%
def checkvalue(a, b):
  return max(a/b, b/a)

# %%
checkbuild1 = list() # ตั้งให้ check2 เป็น list ว่าง เพื่อให้ for loop มันรันค่าใส่ไว่้ใน list
checkbuild2 = list()
for row in tablebuild.iterrows():
    checkbuild1.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน1']))
    checkbuild2.append(checkvalue(row[1]['ราคาทรัพย์'],row[1]['ประเมิน2']))
checkbuild1
checkbuild2
# Out:
# [1.2121212121212122,
#  1.0526315789473684,
#  1.125,
#  1.1428571428571428,
#  1.3,
#  1.2,
#  1.0952380952380953,
#  1.1904761904761905,
#  1.1428571428571428,
#  1.1627906976744187,
#  1.0330578512396693,
#  1.134375,
#  1.1,
#  1.0576923076923077,
#  1.0047846889952152,
#  1.2833333333333334,
#  1.0860219919453369,
#  1.023391812865497,
#  1.0256410256410255,
#  1.1117021276595744,
#  1.0057142857142858,
#  1.2222222222222223,
#  1.02880658436214,
#  1.1733333333333333,
#  1.3888888888888888,
#  1.0125,
#  1.32,
#  1.0227272727272727,
#  1.0263929618768328,
#  1.0263929618768328,
#  1.0047846889952152,
#  1.21,
#  1.1,
#  1.0245714285714285,
#  1.0671936758893281,
#  1.0266666666666666,
#  1.175,
#  1.0606060606060606,
#  1.0227272727272727,
#  1.0214285714285714,
#  1.0389610389610389,
#  1.0526315789473684,
#  1.0101010101010102,
#  2.206896551724138,
#  1.0389610389610389,
#  1.1,
#  1.0047846889952152,
#  1.0833333333333333,
#  1.0,
#  1.0526315789473684,
#  1.09375,
#  1.0,
# ...

# %%
tablebuild['Check1'] = checkbuild1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
tablebuild['Check2'] = checkbuild2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
tablebuild.sort_values(by=['Check2'],ascending=False) #Clean
# Out:
# <ipython-input-146-d8c8acd48700>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tablebuild['Check1'] = checkbuild1 #เพิ่มค่า check1 ไปในคอลัมน์ Check1
# <ipython-input-146-d8c8acd48700>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tablebuild['Check2'] = checkbuild2 #เพิ่มค่า check2 ไปในคอลัมน์ Check2
#                                   post id ความมั่นใจในการเมินราคาทรัพย์  \
# 163  https://nayoo.co/khonkaen/posts/6009                        มั่นใจ
# ...

# %%
idb1MAPE = MAPE(tablebuild['ประเมิน1'],pd.to_numeric(tablebuild['ราคาทรัพย์']))
idb2MAPE = MAPE(tablebuild['ประเมิน2'],pd.to_numeric(tablebuild['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {idb1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idb2MAPE*100:.2f}%')
oneb2two = MAPE(tablebuild['ประเมิน1'],tablebuild['ประเมิน2'])
twob2one = MAPE(tablebuild['ประเมิน2'],tablebuild['ประเมิน1'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((oneb2two)+(twob2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(tablebuild)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 11.70%
# นักประเมิน คนที่ 2 = 9.49%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.53%
# จำนวนทรัพย์ทั้งหมด 91 ทรัพย์

# %% [markdown]
# ##Graph

# %%
databuild = tablebuild[['ความมั่นใจในการเมินราคาทรัพย์', 'ราคาทรัพย์', 'ประเมิน1','ประเมิน2', 'ให้คะแนนทรัพย์']]
databuild.corr(method='pearson')
# Out:
#             ราคาทรัพย์  ประเมิน1  ประเมิน2
# ราคาทรัพย์    1.000000  0.961883  0.978076
# ประเมิน1      0.961883  1.000000  0.954673
# ประเมิน2      0.978076  0.954673  1.000000

# %%
buildcorr = databuild.corr()
sm.graphics.plot_corr(buildcorr, xnames=list(corr.columns), cmap='Blues')
plt.show()

# %%
sns.pairplot(databuild, hue="ความมั่นใจในการเมินราคาทรัพย์")

# %%
sns.pairplot(databuild, hue="ให้คะแนนทรัพย์", diag_kind="hist")
